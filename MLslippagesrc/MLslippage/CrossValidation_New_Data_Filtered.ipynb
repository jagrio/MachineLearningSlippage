# %%
print(__doc__)
import time
start_time = time.time()
from copy import deepcopy, copy
import math
import scipy.io as sio
import shutil
import os
from random import shuffle
import numpy as np
from pylab import *
# from featext2 import *
import matplotlib.pyplot as plt
# %matplotlib inline 
#matplotlib qt
# inline (suitable for ipython only, shown inside browser!) or qt (suitable in general, shown in external window!)
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D #, axes3d
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedKFold, ParameterGrid, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler, normalize
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.decomposition import PCA, KernelPCA, TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression, LogisticRegression, LassoCV, RandomizedLasso
from sklearn.feature_selection import SelectFromModel, SelectKBest, chi2, f_classif, mutual_info_classif, SelectFdr
from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix
from collections import OrderedDict
import re
import datetime
import urllib
import tarfile
import joblib
from joblib import Parallel, delayed, Memory
from tempfile import mkdtemp
import copy_reg
import types
import itertools
from itertools import compress
from collections import Counter

#import multiprocessing
def _pickle_method(m):
    if m.im_self is None:
        return getattr, (m.im_class, m.im_func.func_name)
    else:
        return getattr, (m.im_self, m.im_func.func_name)
copy_reg.pickle(types.MethodType, _pickle_method)

h = .2  # step size in the mesh
names = ["NearNb", "RBFSVM1", "NaiveBayes", "MLP1", "Log.Regr", "RandFor", "AdaBoost", "EnsembleMLP"]
classifiers = [
    KNeighborsClassifier(5),
    SVC(gamma='auto', C=1),
    MLPClassifier(solver='lbfgs',alpha=1e-4,hidden_layer_sizes=(10,10),random_state=1,verbose=True),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
]

cv = StratifiedKFold(n_splits=5, random_state=42)
parameters_clf = [{'n_neighbors':range(3,10)},
              {'kernel':['rbf'], 'C':[0.01,0.1,1,10,100,1000]},
              {'solver':['lbfgs'], 'alpha':[1e-5,1e-2], 'hidden_layer_sizes':[(10,10),(50,50),(100,100)]},
              {'max_depth':[4,7,10,20],'n_estimators':[5,10,20],'max_features':[20,35,50]},
              {'solver':['lbfgs'], 'alpha':[1e-5], 'hidden_layer_sizes':[(len(names)-1,len(names)-1),(len(names)-1,2)]}
             ]
makepipe_parameters_clf = [{'classifier__'+key:p[key] for key in p} for p in parameters_clf]
makepipe_parameters_clf += [{'feature_selection__k': (750,500,100), 'feature_selection__score_func': [mutual_info_classif]},
                            {'decomp__n_components': (100,50)}]
metric = ['accuracy','f1']
dataset = 0 # all datasets (0), dataset 1-2 (1), dataset 3 (2), dataset4 (3)
download = 1 # Download pre-computed (1) data or compute them anew (0)
window = 1024
# Out:
# Automatically created module for IPython interactive environment

# %%
def make_pipe_clf(scaler,feature_selection,decomp,clf):
    order = 1
# order = 1 : first perform feature selection and then apply PCA
# order = 0 : first apply PCA and then reduce the transformed features
    if order:
        pipeline = Pipeline([('scaler', scaler),
                    ('feature_selection', feature_selection),
                    ('decomp', decomp),         
                    ('classifier', clf) ])
#     else:
#         pipeline = Pipeline([('scaler', scaler),
#                     ('decomp', decomp ),                 
#                     ('feature_selection', feature_selection),        
#                     ('classifier', clf) ])
    return pipeline
###########################################################################################
def make_pipe(scaler,feature_selection,decomp,order):
    if order:
        pipeline = Pipeline([('scaler', scaler),
                    ('feature_selection', feature_selection),
                    ('decomp', decomp),         
                     ])
    else:
        pipeline = Pipeline([('scaler', scaler),
                    ('decomp', decomp ),                 
                    ('feature_selection', feature_selection),        
                     ])
    return pipeline

# %%
def get_feat_id(feat_ind, printit = 0): 
    sample_window = 1024
    ##  features:                                                                                  ||      if         ##
##  |----------> time domain      :                                                            || samples = 1024  ##
##  |------------|---> phinyomark : 11+3{shist} -----------------------------> = 14+0.0samples ||             14  ##
##  |------------|---> golz       : 10+samples{acrol} -----------------------> = 10+1.0samples ||           1034  ##
##  |----------> frequency domain :                                                                               ##
##  |------------|---> phinyomark : 3{arco}+4{mf}+3(samples/2+1){RF,IF} -----> =  9+1.0samples ||           1033  ##
##  |------------|---> golz       : 2(samples/2+1){AF,PF} -------------------> =  2+1.0samples ||           1027  ##
##  |------------|--------|-------alltogether--------------------------------> = 35+3.0samples || numfeat = 3108  ##
    # get the feat inds wrt their source : 3rd level
    norm_time_phin = range(0,14)
    norm_freq_phin = range(norm_time_phin[-1] + 1, norm_time_phin[-1] + 9 + sample_window + 1)
    norm_time_golz = range(norm_freq_phin[-1] + 1, norm_freq_phin[-1] + 10 + sample_window + 1)
    norm_freq_golz = range(norm_time_golz[-1] + 1, norm_time_golz[-1] + 2 + sample_window + 1)
    # get the feat inds wrt their domain : 2nd level 
    norm_time_feats = norm_time_phin + norm_time_golz
    norm_freq_feats = norm_freq_phin + norm_freq_golz
    # get the feat inds wrt their prefeat: 1st level 
    norm_feats = norm_time_feats + norm_freq_feats

    # get the feat inds wrt their source : 3rd level
#     np.arange(norm_feats[-1]+1,norm_feats[-1]+1+len(norm_feats))
    disp = norm_feats[-1]+1
    ftfn_time_phin = range(disp ,disp + 14)
    ftfn_freq_phin = range(ftfn_time_phin[-1] + 1, ftfn_time_phin[-1] + 9 + sample_window + 1)
    ftfn_time_golz = range(ftfn_freq_phin[-1] + 1, ftfn_freq_phin[-1] + 10 + sample_window + 1)
    ftfn_freq_golz = range(ftfn_time_golz[-1] + 1, ftfn_time_golz[-1] + 2 + sample_window + 1)
    # get the feat inds wrt their domain : 2nd level 
    ftfn_time_feats = ftfn_time_phin + ftfn_time_golz
    ftfn_freq_feats = ftfn_freq_phin + ftfn_freq_golz
    # get the feat inds wrt their prefeat: 1st level 
    ftfn_feats = ftfn_time_feats + ftfn_freq_feats

    # create the final "reference dictionary"
    id_list = [np.zeros((len(ftfn_feats + norm_feats),1)) for i in range(3)] #3 np.arrays, id_list[0] = level 1 etc
    id_list[0][:norm_feats[-1]+1] = 0 # 0 signifies norm / 1 signifies ft/fn
    id_list[0][norm_feats[-1]+1:] = 1

    id_list[1][:norm_time_phin[-1]+1] = 0 #0 signifies time / 1 signifies freq
    id_list[1][norm_time_phin[-1]+1:norm_freq_phin[-1]+1] = 1
    id_list[1][norm_freq_phin[-1]+1:norm_time_golz[-1]+1] = 0
    id_list[1][norm_time_golz[-1]+1:norm_freq_golz[-1]+1] = 1
    id_list[1][norm_freq_golz[-1]+1:ftfn_time_phin[-1]+1] = 0
    id_list[1][ftfn_time_phin[-1]+1:ftfn_freq_phin[-1]+1] = 1
    id_list[1][ftfn_freq_phin[-1]+1:ftfn_time_golz[-1]+1] = 0
    id_list[1][ftfn_time_golz[-1]+1:] = 1

    id_list[2][:norm_freq_phin[-1]+1] = 0 #0 signifies phinyomark / 1 signifies golz
    id_list[2][norm_freq_phin[-1]+1:norm_freq_golz[-1]+1] = 1
    id_list[2][norm_freq_golz[-1]+1:ftfn_freq_phin[-1]+1] = 0
    id_list[2][ftfn_freq_phin[-1]+1:] = 1 
    
    full_path_id = [np.zeros((len(feat_ind),5)) for i in range(len(feat_ind))]
   
    for ind, val in enumerate(feat_ind):

        full_path_id[ind] = [val, id_list[2][val], id_list[1][val], id_list[0][val]]

        if (printit==1):
            if(full_path_id[ind][1]==0):
                lvl3 = 'Phin'
            else:
                lvl3 = 'Golz'
            if(full_path_id[ind][2]==0):
                lvl2 = 'Time'
            else:
                lvl2 = 'Freq'
            if(full_path_id[ind][3]==0):
                lvl1 = 'Norm'
            else:
                lvl1 = 'Ft/Fn'
            print(feat_ind[ind],featnames[val%(norm_feats[-1]+1)],lvl3,lvl2,lvl1)
    
    return(full_path_id)

# %%
def get_feat_occ(feat_masks):
    #get the number of occurences for each feature after SelectKbest
#     print("If it ain't working, just make sure you're adding the lists instead of concatenating them,")
#     print("if the input isn't a single list you'll get the unhashable error")
    feat_occ = Counter(feat_masks)
    return feat_occ

# %%
class Nested_cv:
    def __init__(self, n_outer_folds = 3, n_inner_folds = 3, n_top =1, state = 42):
        self.n_outer_folds = n_outer_folds
        self.n_inner_folds = n_inner_folds
        self.n_top = n_top
        self.state = state
#         print("constructor %d" %self.state)
                                        
    def set_pipe(self, pip_steps, pip_params):
        n_steps = len(pip_steps)
        if n_steps == 3:
            self.pipe = make_pipe(scaler = pip_steps[0], feature_selection = pip_steps[1], decomp = pip_steps[2])
            self.params = pip_params
        if n_steps == 4:
            self.pipe = make_pipe_clf(scaler = pip_steps[0], feature_selection = pip_steps[1], decomp = pip_steps[2], clf = pip_steps[3])
            self.params = pip_params
        else:
            print ("Number of steps gotta be either 3 or 4, you inserted %d." %n_steps)
        return self.pipe
        
    def fit(self, x_tot, y_tot, verbose = 0):
        self.verbose = verbose
#         print("fit %d" %self.state)
        if self.n_top >1 :
            print ("ACHTUNG! You need to use fit2 for multiple best models!")
            self.fit2(x_tot,y_tot)
        else:
            self.outer_cv = StratifiedKFold(n_splits = self.n_outer_folds, shuffle = True, random_state = self.state)
            self.inner_cv = StratifiedKFold(n_splits = self.n_inner_folds, shuffle = True, random_state = self.state)
            self.grid = GridSearchCV(self.pipe, self.params, cv = self.inner_cv, verbose = self.verbose)       
            self.score = cross_val_score(self.grid, X = x_tot, y = y_tot, cv = self.outer_cv, verbose = self.verbose)

    def get_outer_scores(self):
        return self.score
    
    def get_mean_score(self):
        self.mean_score = self.score.mean()
        print ("Mean score of %d outer folds : %f" %(self.n_outer_folds, self.mean_score ))
        return self.mean_score
    
#     def combinations(self):
#         self.comb = 1
#         for self.key in self.params.keys():
#             self.comb =self.comb*len(self.params[self.key])
#         return self.comb
    
    def get_feat_scores(self):
        return self.total_feats
    
    def get_best_features(self):
        print(self.best_feat_ind)
        return self.best_feat_ind
    
    def print_feat_scores(self):
        self.norm_total_feats = (self.total_feats)/(self.n_inner_folds * self.n_top)
        plt.figure()
        self.rel_score = plt.bar(range(len(self.total_feats)),self.norm_total_feats)
        plt.xlabel("Features")
        plt.ylabel("Score")
        plt.show()
        
    
    def repeated_cv(self,x_tot, y_tot, num_trials):
        self.repeated = np.zeros(num_trials)
        self.rep_feat_scores = np.zeros(x_tot.shape[1])
        self.num_trials = num_trials
        self.state +=1
        for st in range(self.num_trials):
            self.state +=1
            self.fit(x_tot, y_tot)
#             print("repeated %d" %self.state)
            self.out = self.get_outer_scores()
            self.rep_feat_scores += self.get_feat_scores()
            self.repeated[st] = self.out.mean()
            
        plt.figure()
        self.rep_sc_plot = plt.bar(range(num_trials),self.repeated)
        plt.xlabel("Individual trial #")
        plt.ylabel("Outer mean scores")
        plt.show()
    
    def print_rep_feat_scores(self):
        plt.figure()
        self.norm_rep_feats = (self.rep_feat_scores)/(self.n_inner_folds*self.n_top*self.num_trials)
        self.rel_score = plt.bar(range(len(self.total_feats)),self.norm_rep_feats)
        plt.xlabel("Features")
        plt.ylabel("Feature Score")
        plt.show()
        
    def get_rep_feat_scores(self):
        return self.rep_feat_scores
        
    def fit2(self,x_tot, y_tot):
        #the "handwritten" implementation
        self.total_feats = np.zeros(x_tot.shape[1])
        self.classifiers= list(ParameterGrid(self.params))
        self.outer_scores = np.zeros((self.n_top, self.n_outer_folds))
#         self.ncomp = self.params['decomp__n_components']
#         self.best_feat_ind = []
        self.best_pipes = [[],[]]
        self.outer_cv = StratifiedKFold(n_splits = self.n_outer_folds, shuffle = True, random_state = self.state)
        self.inner_cv = StratifiedKFold(n_splits = self.n_inner_folds, shuffle = True, random_state = self.state)
        self.outer = self.outer_cv.split(x_tot,y_tot)
        for self.fold_out, (self.train_ind_out,self.test_ind_out) in enumerate(self.outer):
            top_models = []
            if self.verbose>0 :
                print("Outer loop %d/%d" %((self.fold_out + 1), self.n_outer_folds))
        # split the dataset 
            self.x_trn_out, self.x_tst_out = x_tot[self.train_ind_out], x_tot[self.test_ind_out]
            self.y_trn_out, self.y_tst_out = y_tot[self.train_ind_out], y_tot[self.test_ind_out]  
            
            self.inner_scores = np.zeros((len(self.classifiers),self.n_inner_folds))
            self.inner_mean_scores = np.zeros(len(self.classifiers))
            
            for self.cl_ind, self.clf in enumerate(self.classifiers):
                self.inner = self.inner_cv.split(self.x_trn_out, self.y_trn_out)
                self.nfeat = self.classifiers[self.cl_ind]['feature_selection__k']
                self.best_feat_ind = np.zeros((self.n_top, self.nfeat))


                for self.fold_in, (self.train_ind_in, self.test_ind_in) in enumerate(self.inner): 
                    if self.verbose>0 :
                        print("Inner fold %d/%d" % ((self.fold_in + 1), self.n_inner_folds ))
                    # split the datasets for the inner cv 
                    self.x_trn_in, self.x_tst_in = self.x_trn_out[self.train_ind_in], self.x_trn_out[self.test_ind_in]
                    self.y_trn_in, self.y_tst_in = self.y_trn_out[self.train_ind_in], self.y_trn_out[self.test_ind_in]
                    self.pip = self.pipe.set_params(**self.clf)
                    self.pip.fit(self.x_trn_in,self.y_trn_in)
                    self.inner_scores[self.cl_ind][self.fold_in] = self.pip.score(self.x_tst_in, self.y_tst_in)

            # get the mean performance for every classifier
            self.inner_mean_scores = np.mean(self.inner_scores, axis = 1)
#             print('\n',self.inner_mean_scores)

            # sort the scores, low -> high 
            self.sorted_inds = self.inner_mean_scores.argsort()
            self.sorted_scores = self.inner_mean_scores[self.sorted_inds]

            print ("Best %d models for outer fold %d are: \n " %(self.n_top, (self.fold_out+1)))

#             get the inds of best performing models
            self.temp2 = 0 #iterates over n_top models
            for self.temp_ind in range(-1, -(self.n_top +1), -1):
                self.actual_ind = self.sorted_inds[self.temp_ind]
                self.best_pipes[1].append(self.classifiers[self.actual_ind]) 
                self.best_pipes[0].append(self.fold_out)
                print("model no.%d "%(self.actual_ind + 1))
                print(self.classifiers[self.actual_ind])
                #print the top features selected
                self.best_fs = self.pipe.set_params(**self.classifiers[self.actual_ind]).named_steps['feature_selection']
#                 best_fs = pipeline[actual_ind].named_steps['feature_selection']
                self.best_fs_indd = self.best_fs.get_support(indices = True)
#                 print(self.best_fs_indd)
                self.pipe_fs_unsorted = self.best_fs.scores_
                self.fs_inds = self.pipe_fs_unsorted.argsort()
#                 print(self.fs_inds)
                self.pipe_fs = self.pipe_fs_unsorted[self.fs_inds]
                self.temp3 = 0 # temp3 = 0:number of features
               
                for self.temp_ind2 in range(-1, -(self.nfeat +1), -1):         
                    self.best_feat_ind[self.temp2][self.temp3]=self.fs_inds[self.temp_ind2]
                    self.total_feats[self.fs_inds[self.temp_ind2]]+=1 # feature scores 
                    self.temp3+=1
#                 print(self.total_feats)
                #fit the best classifier on the outer test data
                self.best_pip = self.pipe.set_params(**self.classifiers[self.actual_ind])
                
                self.best_pip.fit(self.x_trn_out, self.y_trn_out)
                
                #get the outer score 
                self.outer_scores[self.temp2, self.fold_out] = self.best_pip.score(self.x_tst_out, self.y_tst_out)
                print("Inner score: %f VS Outer score: %f \n" %(self.inner_mean_scores[self.actual_ind], self.outer_scores[self.temp2, self.fold_out]))
                print ("----------------------------------------------------------")
                self.temp2+=1


#             print("Features selected: \n")
        #     print(best_feat_ind.sort())     
#             print(self.best_feat_ind)
        # print(outer_scores)  
        # print(best_pipes)
        self.score = self.outer_scores

# %%
########################################## Feature Names ###########################################################
####################################################################################################################
##  features:                                                                                  ||      if         ##
##  |----------> time domain      :                                                            || samples = 1024  ##
##  |------------|---> phinyomark : 11+3{shist} -----------------------------> = 14+0.0samples ||             14  ##
##  |------------|---> golz       : 10+samples{acrol} -----------------------> = 10+1.0samples ||           1034  ##
##  |----------> frequency domain :                                                                               ##
##  |------------|---> phinyomark : 3{arco}+4{mf}+3(samples/2+1){RF,IF} -----> =  9+1.0samples ||           1033  ##
##  |------------|---> golz       : 2(samples/2+1){AF,PF} -------------------> =  2+1.0samples ||           1027  ##
##  |------------|--------|-------alltogether--------------------------------> = 35+3.0samples || numfeat = 3108  ##
####################################################################################################################
## Time Domain Phinyomark feats
featnames = ['intsgnl', 'meanabs', 'meanabsslp', 'ssi', 'var', 'rms', 'rng', 'wavl', 'zerox', 'ssc', 'wamp', 
             'shist1', 'shist2', 'shist3']                                                   # 11+3{shist}
## Frequency Domain Phinyomark feats
featnames += ['arco1', 'arco2', 'arco3', 'mnf', 'mdf', 'mmnf', 'mmdf']                       # 3{arco}+4{mf}
featnames += ['reFFT{:03d}'.format(i) for i in range(window/2+1)]                            # samples/2+1{RF}
featnames += ['imFFT{:03d}'.format(i) for i in range(window/2+1)]                            # samples/2+1{IF}
## Time Domain Golz feats
featnames += ['meanv', 'stdr', 'mx', 'rngx', 'rngy', 'med', 'hjorth', 'sentr', 'se', 'ssk']  # 10
featnames += ['acrol{:04d}'.format(i) for i in range(window)]                                # samples{acrol}
## Frequency Domain Golz feats
featnames += ['amFFT{:03d}'.format(i) for i in range(window/2+1)]                            # samples/2+1{AF}
featnames += ['phFFT{:03d}'.format(i) for i in range(window/2+1)]                            # samples/2+1{PF}
# featnames += ['ffaf']                                                                        # 1{ffaf}

# %%
# datasets = np.load('newfeatures_newdata_NOsample_1024_20_10_10000_XYsplit.npz')
# X = datasets['Xsp']
# Y = datasets['Ysp']
XYsplitfile = 'tmp/features/1024_20/newfeatures_newdata_NOsample_filt_1024_20_10_10000_XYsplit.npz'
X = np.load(XYsplitfile)['Xsp']  
Y = np.load(XYsplitfile)['Ysp']

# %%
print([ X[i][j].shape for i in range(len(X)) for j in range(len(X[i]))])
# Out:
# [(8953, 3107), (8953, 3107), (8953, 6214), (8953, 3107), (8953, 3107), (8953, 6214), (8948, 3107), (8948, 3107), (8948, 6214)]

# %%
# i: iterating over finger, j: over featureset 
# (consider keeping only the second featureset and discarding the rest to save some space)
# Performing cross validation for each finger on the second feature set 

cv = KFold(n_splits=5,random_state=42)
# set the pipeline
# def make_pipe_clf(scaler,feature_selection,decomp,clf):
scaler = StandardScaler() ; featsel = SelectKBest(k=1000,score_func= mutual_info_classif)
decomp = PCA(n_components=20)
pipe_list = [make_pipe_clf(scaler,featsel, decomp, classifiers[i]) for i in range(len(classifiers))]
scores = []
for i in range(len(X)):
    data = deepcopy(X[i][2])
    print(i)
    labels = deepcopy(Y[i])
    for pipe in pipe_list:
        score = cross_val_score(estimator = pipe, X = data, y = labels, cv = cv, verbose = 100)
        scores.append(score)
        print ("=============================================================")
        print("Datasets : %d, classifier : %0.4s, 5-fold avg score = %f" %(i, pipe.named_steps['classifier'], np.mean(score)))
        print(score)
        print ("=============================================================")
        
# print pipe_list[1].named_steps['classifier']
# Out:
# 0
# [CV]  ................................................................
# [CV] ................................. , score=0.895564, total= 6.5min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  6.5min remaining:    0.0s
# [CV]  ................................................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3302bd8c3db1> in <module>()
#      15     labels = deepcopy(Y[i])
#      16     for pipe in pipe_list:
# ---> 17         score = cross_val_score(estimator = pipe, X = data, y = labels, cv = cv, verbose = 100)
#      18         scores.append(score)
#      19         print ("=============================================================")
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     138                                               train, test, verbose, None,
#     139                                               fit_params)
# --> 140                       for train, test in cv_iter)
#     141     return np.array(scores)[:, 0]
#     142
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     236             estimator.fit(X_train, **fit_params)
#     237         else:
# --> 238             estimator.fit(X_train, y_train, **fit_params)
#     239
#     240     except Exception as e:
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/pipeline.pyc in fit(self, X, y, **fit_params)
#     266             This estimator
#     267         """
# --> 268         Xt, fit_params = self._fit(X, y, **fit_params)
#     269         if self._final_estimator is not None:
#     270             self._final_estimator.fit(Xt, y, **fit_params)
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/pipeline.pyc in _fit(self, X, y, **fit_params)
#     232                 pass
#     233             elif hasattr(transform, "fit_transform"):
# --> 234                 Xt = transform.fit_transform(Xt, y, **fit_params_steps[name])
#     235             else:
#     236                 Xt = transform.fit(Xt, y, **fit_params_steps[name]) \
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/base.pyc in fit_transform(self, X, y, **fit_params)
#     495         else:
#     496             # fit method of arity 2 (supervised transformation)
# --> 497             return self.fit(X, y, **fit_params).transform(X)
#     498
#     499
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/feature_selection/univariate_selection.pyc in fit(self, X, y)
#     328
#     329         self._check_params(X, y)
# --> 330         score_func_ret = self.score_func(X, y)
#     331         if isinstance(score_func_ret, (list, tuple)):
#     332             self.scores_, self.pvalues_ = score_func_ret
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/feature_selection/mutual_info_.pyc in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     436     check_classification_targets(y)
#     437     return _estimate_mi(X, y, discrete_features, True, n_neighbors,
# --> 438                         copy, random_state)
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/feature_selection/mutual_info_.pyc in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state)
#     283
#     284     mi = [_compute_mi(x, y, discrete_feature, discrete_target) for
# --> 285           x, discrete_feature in moves.zip(_iterate_columns(X), discrete_mask)]
#     286
#     287     return np.array(mi)
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/feature_selection/mutual_info_.pyc in _compute_mi(x, y, x_discrete, y_discrete, n_neighbors)
#     159         return _compute_mi_cd(y, x, n_neighbors)
#     160     elif not x_discrete and y_discrete:
# --> 161         return _compute_mi_cd(x, y, n_neighbors)
#     162     else:
#     163         return _compute_mi_cc(x, y, n_neighbors)
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/feature_selection/mutual_info_.pyc in _compute_mi_cd(c, d, n_neighbors)
#     138     nn.set_params(algorithm='kd_tree')
#     139     nn.fit(c)
# --> 140     ind = nn.radius_neighbors(radius=radius, return_distance=False)
#     141     m_all = np.array([i.size for i in ind])
#     142
#
# /home/ifoundacarrot/.local/lib/python2.7/site-packages/sklearn/neighbors/base.pyc in radius_neighbors(self, X, radius, return_distance)
#     619                     "or set algorithm='brute'" % self._fit_method)
#     620             results = self._tree.query_radius(X, radius,
# --> 621                                               return_distance=return_distance)
#     622             if return_distance:
#     623                 results = results[::-1]
#
# KeyboardInterrupt:

# %%
# cross-validate on the different objects using the dataset from both fingers
data_X = deepcopy(X[2][1])[:-2] # choose the featureset
data_Y = deepcopy(Y[2])[:-2]
surfaces = np.split(data_X,3)
surf_labels = np.split(data_Y,3)

cv = KFold(n_splits=5,random_state=42)
scaler = StandardScaler() ; featsel = SelectKBest(k=1000,score_func= mutual_info_classif)
decomp = PCA(n_components=20)
pipe_list = [make_pipe_clf(scaler,featsel, decomp, classifiers[i]) for i in range(len(classifiers))]
scores = []

for surf_ind, surf_data in enumerate(surfaces):
    print(surf_ind)
    data = surf_data
    labels = surf_labels[surf_ind]
    print(data.shape, labels.shape)
    for pipe in pipe_list:
        score = cross_val_score(estimator = pipe, X = data, y = labels, cv = cv, verbose = 1, n_jobs=-1)
        scores.append(score)
        print ("=============================================================")
        print("Object : %d, classifier : %0.4s, 5-fold avg score = %f" %(surf_ind, pipe.named_steps['classifier'], np.mean(score)))
        print(score)
        print ("=============================================================")
# Out:
# 0
# ((2982, 3107), (2982,))
# =============================================================
# Object : 0, classifier : KNei, 5-fold avg score = 0.944319
# [ 0.95979899  0.9681742   0.91275168  0.93624161  0.94463087]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 0, classifier : SVC(, 5-fold avg score = 0.948015
# [ 0.95142379  0.96482412  0.91610738  0.94798658  0.95973154]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 0, classifier : MLPC, 5-fold avg score = 0.973501
# [ 0.99329983  0.97319933  0.95805369  0.9647651   0.97818792]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 0, classifier : Rand, 5-fold avg score = 0.956738
# [ 0.97487437  0.94639866  0.91610738  0.97315436  0.97315436]
# =============================================================
# 1
# ((2982, 3107), (2982,))
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 1, classifier : KNei, 5-fold avg score = 0.924866
# [ 0.94974874  0.94974874  0.79697987  0.96812081  0.95973154]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 1, classifier : SVC(, 5-fold avg score = 0.921502
# [ 0.9681742   0.95644891  0.81711409  0.97315436  0.89261745]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 1, classifier : MLPC, 5-fold avg score = 0.945989
# [ 0.97487437  0.97654941  0.81375839  0.99161074  0.97315436]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 1, classifier : Rand, 5-fold avg score = 0.919473
# [ 0.99329983  0.97822446  0.80033557  0.95134228  0.87416107]
# =============================================================
# 2
# ((2982, 3107), (2982,))
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 2, classifier : KNei, 5-fold avg score = 0.896387
# [ 0.80904523  0.95812395  0.95973154  0.97818792  0.77684564]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 2, classifier : SVC(, 5-fold avg score = 0.901417
# [ 0.82244556  0.95477387  0.9614094   0.98657718  0.78187919]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 2, classifier : MLPC, 5-fold avg score = 0.935264
# [ 0.94137353  0.97152429  0.98825503  0.97651007  0.79865772]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# =============================================================
# Object : 2, classifier : Rand, 5-fold avg score = 0.916490
# [ 0.96314908  0.89782245  0.96308725  0.98154362  0.77684564]
# =============================================================
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished

# %%
# %%time
# validate between the different objects using the dataset from both fingers

# Version 1: keep alternatively one for training and test on the rest


data_X = deepcopy(X[2][1])[:-2]
data_Y = deepcopy(Y[2])[:-2]
print(data_X.shape)
surfaces = np.split(data_X,3)
surf_labels = np.split(data_Y,3) 
feat_mask = []

scaler = StandardScaler() ; featsel = SelectKBest(k=1000,score_func= mutual_info_classif)
decomp = PCA(n_components=20)
pipe_list = [make_pipe_clf(scaler,featsel, decomp, classifiers[i]) for i in range(len(classifiers))]

for surf_ind, surf_dat in enumerate(surfaces):
    print("Training on surface no. %d" %surf_ind)
    ind_mask = [True, True, True] 
    ind_mask[surf_ind] = False #  the training dataset is flagged by False
    solely_for_printing_mask = [i for i, x in enumerate(ind_mask) if x == True]
    train_x = surf_dat#[::100]
    train_y = surf_labels[surf_ind]#[::100]
    test_x = list(compress(surfaces, ind_mask)) # the rest splits, flagged by True, are kept for testing
    test_y = list(compress(surf_labels,ind_mask))
    
    for pipe_ind,pipe in enumerate(pipe_list):
        print("Fitting classifier no. %d..." %pipe_ind)
        pipe.fit(train_x,train_y) # fit the pipeline for every train set and every clf
        print ("...done fitting")
        feat = list(pipe.named_steps['feature_selection'].get_support(indices = True))
        feat_mask+=feat
        for test_ind, test_d in enumerate(test_x):
            y_pred = pipe.predict(test_d)
            y_true = test_y[test_ind]
            cm = confusion_matrix(y_pred=y_pred, y_true=y_true)
            cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
            print ("=============================================================")
            print("Trained on %d, testing on %d with %0.4s" %(surf_ind, solely_for_printing_mask[test_ind], pipe.named_steps['classifier']))
            print("Prediction accuracy %f" %pipe.score(test_d,y_true))
            print(cm)
            print(classification_report(y_pred=y_pred, y_true = y_true))        
            print ("=============================================================")
    
tot_occs = get_feat_occ(feat_mask)
# Out:
# (8946, 3107)
# Training on surface no. 0
# Fitting classifier no. 0...
# ...done fitting
# =============================================================
# Trained on 0, testing on 1 with KNei
# Prediction accuracy 0.925553
# [[ 0.9876161   0.0123839 ]
#  [ 0.14776884  0.85223116]]
#              precision    recall  f1-score   support
#
#         0.0       0.89      0.99      0.93      1615
#         1.0       0.98      0.85      0.91      1367
#
# avg / total       0.93      0.93      0.92      2982
#
# =============================================================
# =============================================================
# Trained on 0, testing on 2 with KNei
# Prediction accuracy 0.902414
# [[ 0.95992602  0.04007398]
#  [ 0.16617647  0.83382353]]
#              precision    recall  f1-score   support
#
#         0.0       0.87      0.96      0.91      1622
#         1.0       0.95      0.83      0.89      1360
#
# avg / total       0.91      0.90      0.90      2982
#
# =============================================================
# Fitting classifier no. 1...
# ...done fitting
# =============================================================
# Trained on 0, testing on 1 with SVC(
# Prediction accuracy 0.928907
# [[ 0.96965944  0.03034056]
#  [ 0.11923921  0.88076079]]
#              precision    recall  f1-score   support
#
#         0.0       0.91      0.97      0.94      1615
#         1.0       0.96      0.88      0.92      1367
#
# avg / total       0.93      0.93      0.93      2982
#
# =============================================================
# =============================================================
# Trained on 0, testing on 2 with SVC(
# Prediction accuracy 0.919852
# [[ 0.9217016   0.0782984 ]
#  [ 0.08235294  0.91764706]]
#              precision    recall  f1-score   support
#
#         0.0       0.93      0.92      0.93      1622
#         1.0       0.91      0.92      0.91      1360
#
# avg / total       0.92      0.92      0.92      2982
#
# =============================================================
# Fitting classifier no. 2...
# ...done fitting
# =============================================================
# Trained on 0, testing on 1 with MLPC
# Prediction accuracy 0.943662
# [[ 0.97585139  0.02414861]
#  [ 0.09436723  0.90563277]]
#              precision    recall  f1-score   support
#
#         0.0       0.92      0.98      0.95      1615
#         1.0       0.97      0.91      0.94      1367
#
# avg / total       0.95      0.94      0.94      2982
#
# =============================================================
# =============================================================
# Trained on 0, testing on 2 with MLPC
# Prediction accuracy 0.933602
# [[ 0.9377312   0.0622688 ]
#  [ 0.07132353  0.92867647]]
#              precision    recall  f1-score   support
#
#         0.0       0.94      0.94      0.94      1622
#         1.0       0.93      0.93      0.93      1360
#
# avg / total       0.93      0.93      0.93      2982
#
# =============================================================
# Fitting classifier no. 3...
# ...done fitting
# =============================================================
# Trained on 0, testing on 1 with Rand
# Prediction accuracy 0.912475
# [[ 0.8879257   0.1120743 ]
#  [ 0.05852231  0.94147769]]
#              precision    recall  f1-score   support
#
#         0.0       0.95      0.89      0.92      1615
#         1.0       0.88      0.94      0.91      1367
#
# avg / total       0.91      0.91      0.91      2982
#
# =============================================================
# =============================================================
# Trained on 0, testing on 2 with Rand
# Prediction accuracy 0.936284
# [[ 0.91183724  0.08816276]
#  [ 0.03455882  0.96544118]]
#              precision    recall  f1-score   support
#
#         0.0       0.97      0.91      0.94      1622
#         1.0       0.90      0.97      0.93      1360
#
# avg / total       0.94      0.94      0.94      2982
#
# =============================================================
# Training on surface no. 1
# Fitting classifier no. 0...
# ...done fitting
# =============================================================
# Trained on 1, testing on 0 with KNei
# Prediction accuracy 0.963447
# [[ 0.99633476  0.00366524]
#  [ 0.07657993  0.92342007]]
#              precision    recall  f1-score   support
#
#         0.0       0.94      1.00      0.97      1637
#         1.0       1.00      0.92      0.96      1345
#
# avg / total       0.97      0.96      0.96      2982
#
# =============================================================
# =============================================================
# Trained on 1, testing on 2 with KNei
# Prediction accuracy 0.910463
# [[ 0.97903822  0.02096178]
#  [ 0.17132353  0.82867647]]
#              precision    recall  f1-score   support
#
#         0.0       0.87      0.98      0.92      1622
#         1.0       0.97      0.83      0.89      1360
#
# avg / total       0.92      0.91      0.91      2982
#
# =============================================================
# Fitting classifier no. 1...
# ...done fitting
# =============================================================
# Trained on 1, testing on 0 with SVC(
# Prediction accuracy 0.965459
# [[ 0.9908369   0.0091631 ]
#  [ 0.06542751  0.93457249]]
#              precision    recall  f1-score   support
#
#         0.0       0.95      0.99      0.97      1637
#         1.0       0.99      0.93      0.96      1345
#
# avg / total       0.97      0.97      0.97      2982
#
# =============================================================
# =============================================================
# Trained on 1, testing on 2 with SVC(
# Prediction accuracy 0.915828
# [[ 0.95437731  0.04562269]
#  [ 0.13014706  0.86985294]]
#              precision    recall  f1-score   support
#
#         0.0       0.90      0.95      0.93      1622
#         1.0       0.94      0.87      0.90      1360
#
# avg / total       0.92      0.92      0.92      2982
#
# =============================================================
# Fitting classifier no. 2...
# ...done fitting
# =============================================================
# Trained on 1, testing on 0 with MLPC
# Prediction accuracy 0.974849
# [[ 0.99511301  0.00488699]
#  [ 0.04981413  0.95018587]]
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98      1637
#         1.0       0.99      0.95      0.97      1345
#
# avg / total       0.98      0.97      0.97      2982
#
# =============================================================
# =============================================================
# Trained on 1, testing on 2 with MLPC
# Prediction accuracy 0.933266
# [[ 0.96670777  0.03329223]
#  [ 0.10661765  0.89338235]]
#              precision    recall  f1-score   support
#
#         0.0       0.92      0.97      0.94      1622
#         1.0       0.96      0.89      0.92      1360
#
# avg / total       0.93      0.93      0.93      2982
#
# =============================================================
# Fitting classifier no. 3...
# ...done fitting
# =============================================================
# Trained on 1, testing on 0 with Rand
# Prediction accuracy 0.956740
# [[ 0.93646915  0.06353085]
#  [ 0.01858736  0.98141264]]
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.94      0.96      1637
#         1.0       0.93      0.98      0.95      1345
#
# avg / total       0.96      0.96      0.96      2982
#
# =============================================================
# =============================================================
# Trained on 1, testing on 2 with Rand
# Prediction accuracy 0.909121
# [[ 0.89272503  0.10727497]
#  [ 0.07132353  0.92867647]]
#              precision    recall  f1-score   support
#
#         0.0       0.94      0.89      0.91      1622
#         1.0       0.88      0.93      0.90      1360
#
# avg / total       0.91      0.91      0.91      2982
#
# =============================================================
# Training on surface no. 2
# Fitting classifier no. 0...
# ...done fitting
# =============================================================
# Trained on 2, testing on 0 with KNei
# Prediction accuracy 0.912810
# [[ 0.85888821  0.14111179]
#  [ 0.02156134  0.97843866]]
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.86      0.92      1637
#         1.0       0.85      0.98      0.91      1345
#
# avg / total       0.92      0.91      0.91      2982
#
# =============================================================
# =============================================================
# Trained on 2, testing on 1 with KNei
# Prediction accuracy 0.870892
# [[ 0.78142415  0.21857585]
#  [ 0.02340892  0.97659108]]
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.78      0.87      1615
#         1.0       0.79      0.98      0.87      1367
#
# avg / total       0.89      0.87      0.87      2982
#
# =============================================================
# Fitting classifier no. 1...
# ...done fitting
# =============================================================
# Trained on 2, testing on 0 with SVC(
# Prediction accuracy 0.930248
# [[ 0.88087966  0.11912034]
#  [ 0.00966543  0.99033457]]
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.88      0.93      1637
#         1.0       0.87      0.99      0.93      1345
#
# avg / total       0.94      0.93      0.93      2982
#
# =============================================================
# =============================================================
# Trained on 2, testing on 1 with SVC(
# Prediction accuracy 0.877599
# [[ 0.78142415  0.21857585]
#  [ 0.00877835  0.99122165]]
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.78      0.87      1615
#         1.0       0.79      0.99      0.88      1367
#
# avg / total       0.90      0.88      0.88      2982
#
# =============================================================
# Fitting classifier no. 2...
# ...done fitting
# =============================================================
# Trained on 2, testing on 0 with MLPC
# Prediction accuracy 0.953722
# [[ 0.94379963  0.05620037]
#  [ 0.03420074  0.96579926]]
#              precision    recall  f1-score   support
#
#         0.0       0.97      0.94      0.96      1637
#         1.0       0.93      0.97      0.95      1345
#
# avg / total       0.95      0.95      0.95      2982
#
# =============================================================
# =============================================================
# Trained on 2, testing on 1 with MLPC
# Prediction accuracy 0.924883
# [[ 0.91702786  0.08297214]
#  [ 0.0658376   0.9341624 ]]
#              precision    recall  f1-score   support
#
#         0.0       0.94      0.92      0.93      1615
#         1.0       0.91      0.93      0.92      1367
#
# avg / total       0.93      0.92      0.92      2982
#
# =============================================================
# Fitting classifier no. 3...
# ...done fitting
# =============================================================
# Trained on 2, testing on 0 with Rand
# Prediction accuracy 0.880617
# [[ 0.79963348  0.20036652]
#  [ 0.02081784  0.97918216]]
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.80      0.88      1637
#         1.0       0.80      0.98      0.88      1345
#
# avg / total       0.90      0.88      0.88      2982
#
# =============================================================
# =============================================================
# Trained on 2, testing on 1 with Rand
# Prediction accuracy 0.842723
# [[ 0.72321981  0.27678019]
#  [ 0.01609364  0.98390636]]
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.72      0.83      1615
#         1.0       0.75      0.98      0.85      1367
#
# avg / total       0.88      0.84      0.84      2982
#
# =============================================================

# %%
###########################################################################################################
# ==================== use this with Ft/Fn datasets ====================
voi = 12   
always_there = []
offset = 3107
off_feats = [feat_mask[i]+offset for i in range(len(feat_mask))]
off_occs = get_feat_occ(off_feats)
feat_list = []
# print(off_occs)
off_ordered = OrderedDict(sorted(off_occs.items(), key=lambda off_occs: off_occs[1]))
for k,v in off_ordered.items():
    feat_list.append(k)
off_ids = get_feat_id(feat_list,printit = 0)

for k, v in off_ordered.items():
    if v == voi:
        always_there.append(k)
print(len(always_there))
always_there_ids = get_feat_id(always_there, printit = 1)
# Out:
# 336
# (3109, 'meanabsslp', 'Phin', 'Time', 'Ft/Fn')
# (3113, 'rng', 'Phin', 'Time', 'Ft/Fn')
# (3126, 'mmnf', 'Phin', 'Freq', 'Ft/Fn')
# (3127, 'mmdf', 'Phin', 'Freq', 'Ft/Fn')
# (3129, 'reFFT001', 'Phin', 'Freq', 'Ft/Fn')
# (3130, 'reFFT002', 'Phin', 'Freq', 'Ft/Fn')
# (3131, 'reFFT003', 'Phin', 'Freq', 'Ft/Fn')
# (3132, 'reFFT004', 'Phin', 'Freq', 'Ft/Fn')
# (3133, 'reFFT005', 'Phin', 'Freq', 'Ft/Fn')
# (3134, 'reFFT006', 'Phin', 'Freq', 'Ft/Fn')
# (3135, 'reFFT007', 'Phin', 'Freq', 'Ft/Fn')
# (3136, 'reFFT008', 'Phin', 'Freq', 'Ft/Fn')
# (3137, 'reFFT009', 'Phin', 'Freq', 'Ft/Fn')
# (3138, 'reFFT010', 'Phin', 'Freq', 'Ft/Fn')
# (3139, 'reFFT011', 'Phin', 'Freq', 'Ft/Fn')
# (3140, 'reFFT012', 'Phin', 'Freq', 'Ft/Fn')
# (3142, 'reFFT014', 'Phin', 'Freq', 'Ft/Fn')
# (3457, 'reFFT329', 'Phin', 'Freq', 'Ft/Fn')
# (3459, 'reFFT331', 'Phin', 'Freq', 'Ft/Fn')
# (3461, 'reFFT333', 'Phin', 'Freq', 'Ft/Fn')
# (3466, 'reFFT338', 'Phin', 'Freq', 'Ft/Fn')
# (3473, 'reFFT345', 'Phin', 'Freq', 'Ft/Fn')
# (3479, 'reFFT351', 'Phin', 'Freq', 'Ft/Fn')
# (3480, 'reFFT352', 'Phin', 'Freq', 'Ft/Fn')
# (3483, 'reFFT355', 'Phin', 'Freq', 'Ft/Fn')
# (3484, 'reFFT356', 'Phin', 'Freq', 'Ft/Fn')
# (3487, 'reFFT359', 'Phin', 'Freq', 'Ft/Fn')
# (3490, 'reFFT362', 'Phin', 'Freq', 'Ft/Fn')
# (3491, 'reFFT363', 'Phin', 'Freq', 'Ft/Fn')
# (3492, 'reFFT364', 'Phin', 'Freq', 'Ft/Fn')
# (3493, 'reFFT365', 'Phin', 'Freq', 'Ft/Fn')
# (3497, 'reFFT369', 'Phin', 'Freq', 'Ft/Fn')
# (3500, 'reFFT372', 'Phin', 'Freq', 'Ft/Fn')
# (3501, 'reFFT373', 'Phin', 'Freq', 'Ft/Fn')
# (3502, 'reFFT374', 'Phin', 'Freq', 'Ft/Fn')
# (3503, 'reFFT375', 'Phin', 'Freq', 'Ft/Fn')
# (3504, 'reFFT376', 'Phin', 'Freq', 'Ft/Fn')
# (3505, 'reFFT377', 'Phin', 'Freq', 'Ft/Fn')
# (3506, 'reFFT378', 'Phin', 'Freq', 'Ft/Fn')
# (3509, 'reFFT381', 'Phin', 'Freq', 'Ft/Fn')
# (3510, 'reFFT382', 'Phin', 'Freq', 'Ft/Fn')
# (3511, 'reFFT383', 'Phin', 'Freq', 'Ft/Fn')
# (3513, 'reFFT385', 'Phin', 'Freq', 'Ft/Fn')
# (3514, 'reFFT386', 'Phin', 'Freq', 'Ft/Fn')
# (3515, 'reFFT387', 'Phin', 'Freq', 'Ft/Fn')
# (3517, 'reFFT389', 'Phin', 'Freq', 'Ft/Fn')
# (3518, 'reFFT390', 'Phin', 'Freq', 'Ft/Fn')
# (3519, 'reFFT391', 'Phin', 'Freq', 'Ft/Fn')
# (3520, 'reFFT392', 'Phin', 'Freq', 'Ft/Fn')
# (3521, 'reFFT393', 'Phin', 'Freq', 'Ft/Fn')
# (3522, 'reFFT394', 'Phin', 'Freq', 'Ft/Fn')
# (3523, 'reFFT395', 'Phin', 'Freq', 'Ft/Fn')
# (3524, 'reFFT396', 'Phin', 'Freq', 'Ft/Fn')
# (3525, 'reFFT397', 'Phin', 'Freq', 'Ft/Fn')
# (3526, 'reFFT398', 'Phin', 'Freq', 'Ft/Fn')
# (3527, 'reFFT399', 'Phin', 'Freq', 'Ft/Fn')
# (3528, 'reFFT400', 'Phin', 'Freq', 'Ft/Fn')
# (3529, 'reFFT401', 'Phin', 'Freq', 'Ft/Fn')
# (3530, 'reFFT402', 'Phin', 'Freq', 'Ft/Fn')
# (3531, 'reFFT403', 'Phin', 'Freq', 'Ft/Fn')
# (3532, 'reFFT404', 'Phin', 'Freq', 'Ft/Fn')
# (3533, 'reFFT405', 'Phin', 'Freq', 'Ft/Fn')
# (3534, 'reFFT406', 'Phin', 'Freq', 'Ft/Fn')
# (3535, 'reFFT407', 'Phin', 'Freq', 'Ft/Fn')
# (3536, 'reFFT408', 'Phin', 'Freq', 'Ft/Fn')
# (3537, 'reFFT409', 'Phin', 'Freq', 'Ft/Fn')
# (3538, 'reFFT410', 'Phin', 'Freq', 'Ft/Fn')
# (3539, 'reFFT411', 'Phin', 'Freq', 'Ft/Fn')
# (3540, 'reFFT412', 'Phin', 'Freq', 'Ft/Fn')
# (3541, 'reFFT413', 'Phin', 'Freq', 'Ft/Fn')
# (3542, 'reFFT414', 'Phin', 'Freq', 'Ft/Fn')
# (3543, 'reFFT415', 'Phin', 'Freq', 'Ft/Fn')
# (3544, 'reFFT416', 'Phin', 'Freq', 'Ft/Fn')
# (3545, 'reFFT417', 'Phin', 'Freq', 'Ft/Fn')
# (3546, 'reFFT418', 'Phin', 'Freq', 'Ft/Fn')
# (3547, 'reFFT419', 'Phin', 'Freq', 'Ft/Fn')
# (3548, 'reFFT420', 'Phin', 'Freq', 'Ft/Fn')
# (3549, 'reFFT421', 'Phin', 'Freq', 'Ft/Fn')
# (3550, 'reFFT422', 'Phin', 'Freq', 'Ft/Fn')
# (3551, 'reFFT423', 'Phin', 'Freq', 'Ft/Fn')
# (3552, 'reFFT424', 'Phin', 'Freq', 'Ft/Fn')
# (3553, 'reFFT425', 'Phin', 'Freq', 'Ft/Fn')
# (3554, 'reFFT426', 'Phin', 'Freq', 'Ft/Fn')
# (3555, 'reFFT427', 'Phin', 'Freq', 'Ft/Fn')
# (3556, 'reFFT428', 'Phin', 'Freq', 'Ft/Fn')
# (3557, 'reFFT429', 'Phin', 'Freq', 'Ft/Fn')
# (3558, 'reFFT430', 'Phin', 'Freq', 'Ft/Fn')
# (3559, 'reFFT431', 'Phin', 'Freq', 'Ft/Fn')
# (3560, 'reFFT432', 'Phin', 'Freq', 'Ft/Fn')
# (3561, 'reFFT433', 'Phin', 'Freq', 'Ft/Fn')
# (3562, 'reFFT434', 'Phin', 'Freq', 'Ft/Fn')
# (3563, 'reFFT435', 'Phin', 'Freq', 'Ft/Fn')
# (3564, 'reFFT436', 'Phin', 'Freq', 'Ft/Fn')
# (3565, 'reFFT437', 'Phin', 'Freq', 'Ft/Fn')
# (3566, 'reFFT438', 'Phin', 'Freq', 'Ft/Fn')
# (3567, 'reFFT439', 'Phin', 'Freq', 'Ft/Fn')
# (3568, 'reFFT440', 'Phin', 'Freq', 'Ft/Fn')
# (3569, 'reFFT441', 'Phin', 'Freq', 'Ft/Fn')
# (3570, 'reFFT442', 'Phin', 'Freq', 'Ft/Fn')
# (3571, 'reFFT443', 'Phin', 'Freq', 'Ft/Fn')
# (3572, 'reFFT444', 'Phin', 'Freq', 'Ft/Fn')
# (3573, 'reFFT445', 'Phin', 'Freq', 'Ft/Fn')
# (3574, 'reFFT446', 'Phin', 'Freq', 'Ft/Fn')
# (3575, 'reFFT447', 'Phin', 'Freq', 'Ft/Fn')
# (3576, 'reFFT448', 'Phin', 'Freq', 'Ft/Fn')
# (3577, 'reFFT449', 'Phin', 'Freq', 'Ft/Fn')
# (3578, 'reFFT450', 'Phin', 'Freq', 'Ft/Fn')
# (3579, 'reFFT451', 'Phin', 'Freq', 'Ft/Fn')
# (3580, 'reFFT452', 'Phin', 'Freq', 'Ft/Fn')
# (3581, 'reFFT453', 'Phin', 'Freq', 'Ft/Fn')
# (3582, 'reFFT454', 'Phin', 'Freq', 'Ft/Fn')
# (3583, 'reFFT455', 'Phin', 'Freq', 'Ft/Fn')
# (3584, 'reFFT456', 'Phin', 'Freq', 'Ft/Fn')
# (3585, 'reFFT457', 'Phin', 'Freq', 'Ft/Fn')
# (3586, 'reFFT458', 'Phin', 'Freq', 'Ft/Fn')
# (3587, 'reFFT459', 'Phin', 'Freq', 'Ft/Fn')
# (3588, 'reFFT460', 'Phin', 'Freq', 'Ft/Fn')
# (3589, 'reFFT461', 'Phin', 'Freq', 'Ft/Fn')
# (3590, 'reFFT462', 'Phin', 'Freq', 'Ft/Fn')
# (3591, 'reFFT463', 'Phin', 'Freq', 'Ft/Fn')
# (3592, 'reFFT464', 'Phin', 'Freq', 'Ft/Fn')
# (3593, 'reFFT465', 'Phin', 'Freq', 'Ft/Fn')
# (3594, 'reFFT466', 'Phin', 'Freq', 'Ft/Fn')
# (3595, 'reFFT467', 'Phin', 'Freq', 'Ft/Fn')
# (3596, 'reFFT468', 'Phin', 'Freq', 'Ft/Fn')
# (3597, 'reFFT469', 'Phin', 'Freq', 'Ft/Fn')
# (3598, 'reFFT470', 'Phin', 'Freq', 'Ft/Fn')
# (3599, 'reFFT471', 'Phin', 'Freq', 'Ft/Fn')
# (3600, 'reFFT472', 'Phin', 'Freq', 'Ft/Fn')
# (3601, 'reFFT473', 'Phin', 'Freq', 'Ft/Fn')
# (3602, 'reFFT474', 'Phin', 'Freq', 'Ft/Fn')
# (3603, 'reFFT475', 'Phin', 'Freq', 'Ft/Fn')
# (3604, 'reFFT476', 'Phin', 'Freq', 'Ft/Fn')
# (3605, 'reFFT477', 'Phin', 'Freq', 'Ft/Fn')
# (3606, 'reFFT478', 'Phin', 'Freq', 'Ft/Fn')
# (3607, 'reFFT479', 'Phin', 'Freq', 'Ft/Fn')
# (3608, 'reFFT480', 'Phin', 'Freq', 'Ft/Fn')
# (3609, 'reFFT481', 'Phin', 'Freq', 'Ft/Fn')
# (3610, 'reFFT482', 'Phin', 'Freq', 'Ft/Fn')
# (3611, 'reFFT483', 'Phin', 'Freq', 'Ft/Fn')
# (3612, 'reFFT484', 'Phin', 'Freq', 'Ft/Fn')
# (3613, 'reFFT485', 'Phin', 'Freq', 'Ft/Fn')
# (3614, 'reFFT486', 'Phin', 'Freq', 'Ft/Fn')
# (3615, 'reFFT487', 'Phin', 'Freq', 'Ft/Fn')
# (3616, 'reFFT488', 'Phin', 'Freq', 'Ft/Fn')
# (3617, 'reFFT489', 'Phin', 'Freq', 'Ft/Fn')
# (3618, 'reFFT490', 'Phin', 'Freq', 'Ft/Fn')
# (3619, 'reFFT491', 'Phin', 'Freq', 'Ft/Fn')
# (3620, 'reFFT492', 'Phin', 'Freq', 'Ft/Fn')
# (3621, 'reFFT493', 'Phin', 'Freq', 'Ft/Fn')
# (3622, 'reFFT494', 'Phin', 'Freq', 'Ft/Fn')
# (3623, 'reFFT495', 'Phin', 'Freq', 'Ft/Fn')
# (3624, 'reFFT496', 'Phin', 'Freq', 'Ft/Fn')
# (3625, 'reFFT497', 'Phin', 'Freq', 'Ft/Fn')
# (3626, 'reFFT498', 'Phin', 'Freq', 'Ft/Fn')
# (3627, 'reFFT499', 'Phin', 'Freq', 'Ft/Fn')
# (3628, 'reFFT500', 'Phin', 'Freq', 'Ft/Fn')
# (3629, 'reFFT501', 'Phin', 'Freq', 'Ft/Fn')
# (3630, 'reFFT502', 'Phin', 'Freq', 'Ft/Fn')
# (3631, 'reFFT503', 'Phin', 'Freq', 'Ft/Fn')
# (3632, 'reFFT504', 'Phin', 'Freq', 'Ft/Fn')
# (3633, 'reFFT505', 'Phin', 'Freq', 'Ft/Fn')
# (3634, 'reFFT506', 'Phin', 'Freq', 'Ft/Fn')
# (3635, 'reFFT507', 'Phin', 'Freq', 'Ft/Fn')
# (3636, 'reFFT508', 'Phin', 'Freq', 'Ft/Fn')
# (3637, 'reFFT509', 'Phin', 'Freq', 'Ft/Fn')
# (3638, 'reFFT510', 'Phin', 'Freq', 'Ft/Fn')
# (3639, 'reFFT511', 'Phin', 'Freq', 'Ft/Fn')
# (3640, 'reFFT512', 'Phin', 'Freq', 'Ft/Fn')
# (3642, 'imFFT001', 'Phin', 'Freq', 'Ft/Fn')
# (3643, 'imFFT002', 'Phin', 'Freq', 'Ft/Fn')
# (3644, 'imFFT003', 'Phin', 'Freq', 'Ft/Fn')
# (3645, 'imFFT004', 'Phin', 'Freq', 'Ft/Fn')
# (3646, 'imFFT005', 'Phin', 'Freq', 'Ft/Fn')
# (3647, 'imFFT006', 'Phin', 'Freq', 'Ft/Fn')
# (3648, 'imFFT007', 'Phin', 'Freq', 'Ft/Fn')
# (3649, 'imFFT008', 'Phin', 'Freq', 'Ft/Fn')
# (3650, 'imFFT009', 'Phin', 'Freq', 'Ft/Fn')
# (3651, 'imFFT010', 'Phin', 'Freq', 'Ft/Fn')
# (3652, 'imFFT011', 'Phin', 'Freq', 'Ft/Fn')
# (3653, 'imFFT012', 'Phin', 'Freq', 'Ft/Fn')
# (3654, 'imFFT013', 'Phin', 'Freq', 'Ft/Fn')
# (3655, 'imFFT014', 'Phin', 'Freq', 'Ft/Fn')
# (3657, 'imFFT016', 'Phin', 'Freq', 'Ft/Fn')
# (3658, 'imFFT017', 'Phin', 'Freq', 'Ft/Fn')
# (3659, 'imFFT018', 'Phin', 'Freq', 'Ft/Fn')
# (3660, 'imFFT019', 'Phin', 'Freq', 'Ft/Fn')
# (3661, 'imFFT020', 'Phin', 'Freq', 'Ft/Fn')
# (3662, 'imFFT021', 'Phin', 'Freq', 'Ft/Fn')
# (3663, 'imFFT022', 'Phin', 'Freq', 'Ft/Fn')
# (3664, 'imFFT023', 'Phin', 'Freq', 'Ft/Fn')
# (3670, 'imFFT029', 'Phin', 'Freq', 'Ft/Fn')
# (3676, 'imFFT035', 'Phin', 'Freq', 'Ft/Fn')
# (3999, 'imFFT358', 'Phin', 'Freq', 'Ft/Fn')
# (4027, 'imFFT386', 'Phin', 'Freq', 'Ft/Fn')
# (4045, 'imFFT404', 'Phin', 'Freq', 'Ft/Fn')
# (4055, 'imFFT414', 'Phin', 'Freq', 'Ft/Fn')
# (4060, 'imFFT419', 'Phin', 'Freq', 'Ft/Fn')
# (4061, 'imFFT420', 'Phin', 'Freq', 'Ft/Fn')
# (4062, 'imFFT421', 'Phin', 'Freq', 'Ft/Fn')
# (4063, 'imFFT422', 'Phin', 'Freq', 'Ft/Fn')
# (4078, 'imFFT437', 'Phin', 'Freq', 'Ft/Fn')
# (4080, 'imFFT439', 'Phin', 'Freq', 'Ft/Fn')
# (4083, 'imFFT442', 'Phin', 'Freq', 'Ft/Fn')
# (4085, 'imFFT444', 'Phin', 'Freq', 'Ft/Fn')
# (4086, 'imFFT445', 'Phin', 'Freq', 'Ft/Fn')
# (4092, 'imFFT451', 'Phin', 'Freq', 'Ft/Fn')
# (4094, 'imFFT453', 'Phin', 'Freq', 'Ft/Fn')
# (4104, 'imFFT463', 'Phin', 'Freq', 'Ft/Fn')
# (4106, 'imFFT465', 'Phin', 'Freq', 'Ft/Fn')
# (4110, 'imFFT469', 'Phin', 'Freq', 'Ft/Fn')
# (4114, 'imFFT473', 'Phin', 'Freq', 'Ft/Fn')
# (4126, 'imFFT485', 'Phin', 'Freq', 'Ft/Fn')
# (4130, 'imFFT489', 'Phin', 'Freq', 'Ft/Fn')
# (4132, 'imFFT491', 'Phin', 'Freq', 'Ft/Fn')
# (4155, 'stdr', 'Golz', 'Time', 'Ft/Fn')
# (4156, 'mx', 'Golz', 'Time', 'Ft/Fn')
# (4158, 'rngy', 'Golz', 'Time', 'Ft/Fn')
# (4163, 'ssk', 'Golz', 'Time', 'Ft/Fn')
# (4165, 'acrol0001', 'Golz', 'Time', 'Ft/Fn')
# (4167, 'acrol0003', 'Golz', 'Time', 'Ft/Fn')
# (4170, 'acrol0006', 'Golz', 'Time', 'Ft/Fn')
# (4172, 'acrol0008', 'Golz', 'Time', 'Ft/Fn')
# (4175, 'acrol0011', 'Golz', 'Time', 'Ft/Fn')
# (4177, 'acrol0013', 'Golz', 'Time', 'Ft/Fn')
# (4178, 'acrol0014', 'Golz', 'Time', 'Ft/Fn')
# (4179, 'acrol0015', 'Golz', 'Time', 'Ft/Fn')
# (4180, 'acrol0016', 'Golz', 'Time', 'Ft/Fn')
# (4183, 'acrol0019', 'Golz', 'Time', 'Ft/Fn')
# (4184, 'acrol0020', 'Golz', 'Time', 'Ft/Fn')
# (4185, 'acrol0021', 'Golz', 'Time', 'Ft/Fn')
# (4186, 'acrol0022', 'Golz', 'Time', 'Ft/Fn')
# (4187, 'acrol0023', 'Golz', 'Time', 'Ft/Fn')
# (4188, 'acrol0024', 'Golz', 'Time', 'Ft/Fn')
# (4189, 'acrol0025', 'Golz', 'Time', 'Ft/Fn')
# (4190, 'acrol0026', 'Golz', 'Time', 'Ft/Fn')
# (4191, 'acrol0027', 'Golz', 'Time', 'Ft/Fn')
# (4192, 'acrol0028', 'Golz', 'Time', 'Ft/Fn')
# (4193, 'acrol0029', 'Golz', 'Time', 'Ft/Fn')
# (4194, 'acrol0030', 'Golz', 'Time', 'Ft/Fn')
# (4195, 'acrol0031', 'Golz', 'Time', 'Ft/Fn')
# (4197, 'acrol0033', 'Golz', 'Time', 'Ft/Fn')
# (4200, 'acrol0036', 'Golz', 'Time', 'Ft/Fn')
# (4203, 'acrol0039', 'Golz', 'Time', 'Ft/Fn')
# (4204, 'acrol0040', 'Golz', 'Time', 'Ft/Fn')
# (4205, 'acrol0041', 'Golz', 'Time', 'Ft/Fn')
# (4206, 'acrol0042', 'Golz', 'Time', 'Ft/Fn')
# (4207, 'acrol0043', 'Golz', 'Time', 'Ft/Fn')
# (4208, 'acrol0044', 'Golz', 'Time', 'Ft/Fn')
# (4210, 'acrol0046', 'Golz', 'Time', 'Ft/Fn')
# (4211, 'acrol0047', 'Golz', 'Time', 'Ft/Fn')
# (4212, 'acrol0048', 'Golz', 'Time', 'Ft/Fn')
# (4215, 'acrol0051', 'Golz', 'Time', 'Ft/Fn')
# (4218, 'acrol0054', 'Golz', 'Time', 'Ft/Fn')
# (4246, 'acrol0082', 'Golz', 'Time', 'Ft/Fn')
# (4250, 'acrol0086', 'Golz', 'Time', 'Ft/Fn')
# (4368, 'acrol0204', 'Golz', 'Time', 'Ft/Fn')
# (4369, 'acrol0205', 'Golz', 'Time', 'Ft/Fn')
# (4381, 'acrol0217', 'Golz', 'Time', 'Ft/Fn')
# (4382, 'acrol0218', 'Golz', 'Time', 'Ft/Fn')
# (4484, 'acrol0320', 'Golz', 'Time', 'Ft/Fn')
# (4539, 'acrol0375', 'Golz', 'Time', 'Ft/Fn')
# (4664, 'acrol0500', 'Golz', 'Time', 'Ft/Fn')
# (4901, 'acrol0737', 'Golz', 'Time', 'Ft/Fn')
# (5189, 'amFFT001', 'Golz', 'Freq', 'Ft/Fn')
# (5190, 'amFFT002', 'Golz', 'Freq', 'Ft/Fn')
# (5191, 'amFFT003', 'Golz', 'Freq', 'Ft/Fn')
# (5192, 'amFFT004', 'Golz', 'Freq', 'Ft/Fn')
# (5193, 'amFFT005', 'Golz', 'Freq', 'Ft/Fn')
# (5194, 'amFFT006', 'Golz', 'Freq', 'Ft/Fn')
# (5195, 'amFFT007', 'Golz', 'Freq', 'Ft/Fn')
# (5196, 'amFFT008', 'Golz', 'Freq', 'Ft/Fn')
# (5197, 'amFFT009', 'Golz', 'Freq', 'Ft/Fn')
# (5198, 'amFFT010', 'Golz', 'Freq', 'Ft/Fn')
# (5199, 'amFFT011', 'Golz', 'Freq', 'Ft/Fn')
# (5200, 'amFFT012', 'Golz', 'Freq', 'Ft/Fn')
# (5201, 'amFFT013', 'Golz', 'Freq', 'Ft/Fn')
# (5202, 'amFFT014', 'Golz', 'Freq', 'Ft/Fn')
# (5203, 'amFFT015', 'Golz', 'Freq', 'Ft/Fn')
# (5204, 'amFFT016', 'Golz', 'Freq', 'Ft/Fn')
# (5205, 'amFFT017', 'Golz', 'Freq', 'Ft/Fn')
# (5206, 'amFFT018', 'Golz', 'Freq', 'Ft/Fn')
# (5207, 'amFFT019', 'Golz', 'Freq', 'Ft/Fn')
# (5208, 'amFFT020', 'Golz', 'Freq', 'Ft/Fn')
# (5209, 'amFFT021', 'Golz', 'Freq', 'Ft/Fn')
# (5210, 'amFFT022', 'Golz', 'Freq', 'Ft/Fn')
# (5211, 'amFFT023', 'Golz', 'Freq', 'Ft/Fn')
# (5212, 'amFFT024', 'Golz', 'Freq', 'Ft/Fn')
# (5213, 'amFFT025', 'Golz', 'Freq', 'Ft/Fn')
# (5214, 'amFFT026', 'Golz', 'Freq', 'Ft/Fn')
# (5215, 'amFFT027', 'Golz', 'Freq', 'Ft/Fn')
# (5217, 'amFFT029', 'Golz', 'Freq', 'Ft/Fn')
# (5218, 'amFFT030', 'Golz', 'Freq', 'Ft/Fn')
# (5219, 'amFFT031', 'Golz', 'Freq', 'Ft/Fn')
# (5220, 'amFFT032', 'Golz', 'Freq', 'Ft/Fn')
# (5221, 'amFFT033', 'Golz', 'Freq', 'Ft/Fn')
# (5222, 'amFFT034', 'Golz', 'Freq', 'Ft/Fn')
# (5223, 'amFFT035', 'Golz', 'Freq', 'Ft/Fn')
# (5225, 'amFFT037', 'Golz', 'Freq', 'Ft/Fn')
# (5226, 'amFFT038', 'Golz', 'Freq', 'Ft/Fn')
# (5702, 'phFFT001', 'Golz', 'Freq', 'Ft/Fn')
# (5703, 'phFFT002', 'Golz', 'Freq', 'Ft/Fn')
# (5704, 'phFFT003', 'Golz', 'Freq', 'Ft/Fn')
# (5705, 'phFFT004', 'Golz', 'Freq', 'Ft/Fn')
# (5706, 'phFFT005', 'Golz', 'Freq', 'Ft/Fn')
# (5707, 'phFFT006', 'Golz', 'Freq', 'Ft/Fn')
# (5708, 'phFFT007', 'Golz', 'Freq', 'Ft/Fn')
# (5709, 'phFFT008', 'Golz', 'Freq', 'Ft/Fn')
# (5710, 'phFFT009', 'Golz', 'Freq', 'Ft/Fn')
# (5711, 'phFFT010', 'Golz', 'Freq', 'Ft/Fn')
# (5712, 'phFFT011', 'Golz', 'Freq', 'Ft/Fn')
# (5713, 'phFFT012', 'Golz', 'Freq', 'Ft/Fn')
# (5714, 'phFFT013', 'Golz', 'Freq', 'Ft/Fn')
# (5715, 'phFFT014', 'Golz', 'Freq', 'Ft/Fn')
# (5716, 'phFFT015', 'Golz', 'Freq', 'Ft/Fn')
# (5717, 'phFFT016', 'Golz', 'Freq', 'Ft/Fn')
# (5718, 'phFFT017', 'Golz', 'Freq', 'Ft/Fn')
# (5719, 'phFFT018', 'Golz', 'Freq', 'Ft/Fn')
# (5720, 'phFFT019', 'Golz', 'Freq', 'Ft/Fn')
# (5721, 'phFFT020', 'Golz', 'Freq', 'Ft/Fn')
# (5722, 'phFFT021', 'Golz', 'Freq', 'Ft/Fn')
# (5723, 'phFFT022', 'Golz', 'Freq', 'Ft/Fn')
# (5724, 'phFFT023', 'Golz', 'Freq', 'Ft/Fn')
# (5725, 'phFFT024', 'Golz', 'Freq', 'Ft/Fn')
# (5726, 'phFFT025', 'Golz', 'Freq', 'Ft/Fn')
# (5727, 'phFFT026', 'Golz', 'Freq', 'Ft/Fn')
# (5728, 'phFFT027', 'Golz', 'Freq', 'Ft/Fn')
# (5730, 'phFFT029', 'Golz', 'Freq', 'Ft/Fn')
# (5731, 'phFFT030', 'Golz', 'Freq', 'Ft/Fn')
# (5732, 'phFFT031', 'Golz', 'Freq', 'Ft/Fn')
# (5733, 'phFFT032', 'Golz', 'Freq', 'Ft/Fn')
# (5734, 'phFFT033', 'Golz', 'Freq', 'Ft/Fn')
# (5735, 'phFFT034', 'Golz', 'Freq', 'Ft/Fn')
# (5736, 'phFFT035', 'Golz', 'Freq', 'Ft/Fn')
# (5738, 'phFFT037', 'Golz', 'Freq', 'Ft/Fn')
# (5739, 'phFFT038', 'Golz', 'Freq', 'Ft/Fn')

# %%
from collections import OrderedDict
# they're sorted in ascending order !!!!

feat_list = []
asd = OrderedDict(sorted(tot_occs.items(), key=lambda tot_occs: tot_occs[1]))
for k,v in asd.items():
    feat_list.append(k)
nio = get_feat_id(feat_list,printit = 1)
# print feat_list
# Out:
# (18, 'mdf', 'Phin', 'Freq', 'Norm')
# (1895, 'acrol0838', 'Golz', 'Time', 'Norm')
# (3029, 'phFFT435', 'Golz', 'Freq', 'Norm')
# (3053, 'phFFT459', 'Golz', 'Freq', 'Norm')
# (1973, 'acrol0916', 'Golz', 'Time', 'Norm')
# (2407, 'amFFT326', 'Golz', 'Freq', 'Norm')
# (36, 'reFFT015', 'Phin', 'Freq', 'Norm')
# (40, 'reFFT019', 'Phin', 'Freq', 'Norm')
# (41, 'reFFT020', 'Phin', 'Freq', 'Norm')
# (42, 'reFFT021', 'Phin', 'Freq', 'Norm')
# (43, 'reFFT022', 'Phin', 'Freq', 'Norm')
# (44, 'reFFT023', 'Phin', 'Freq', 'Norm')
# (45, 'reFFT024', 'Phin', 'Freq', 'Norm')
# (290, 'reFFT269', 'Phin', 'Freq', 'Norm')
# (294, 'reFFT273', 'Phin', 'Freq', 'Norm')
# (296, 'reFFT275', 'Phin', 'Freq', 'Norm')
# (297, 'reFFT276', 'Phin', 'Freq', 'Norm')
# (299, 'reFFT278', 'Phin', 'Freq', 'Norm')
# (300, 'reFFT279', 'Phin', 'Freq', 'Norm')
# (301, 'reFFT280', 'Phin', 'Freq', 'Norm')
# (302, 'reFFT281', 'Phin', 'Freq', 'Norm')
# (303, 'reFFT282', 'Phin', 'Freq', 'Norm')
# (305, 'reFFT284', 'Phin', 'Freq', 'Norm')
# (306, 'reFFT285', 'Phin', 'Freq', 'Norm')
# (307, 'reFFT286', 'Phin', 'Freq', 'Norm')
# (308, 'reFFT287', 'Phin', 'Freq', 'Norm')
# (309, 'reFFT288', 'Phin', 'Freq', 'Norm')
# (310, 'reFFT289', 'Phin', 'Freq', 'Norm')
# (311, 'reFFT290', 'Phin', 'Freq', 'Norm')
# (312, 'reFFT291', 'Phin', 'Freq', 'Norm')
# (313, 'reFFT292', 'Phin', 'Freq', 'Norm')
# (314, 'reFFT293', 'Phin', 'Freq', 'Norm')
# (315, 'reFFT294', 'Phin', 'Freq', 'Norm')
# (316, 'reFFT295', 'Phin', 'Freq', 'Norm')
# (317, 'reFFT296', 'Phin', 'Freq', 'Norm')
# (318, 'reFFT297', 'Phin', 'Freq', 'Norm')
# (319, 'reFFT298', 'Phin', 'Freq', 'Norm')
# (320, 'reFFT299', 'Phin', 'Freq', 'Norm')
# (321, 'reFFT300', 'Phin', 'Freq', 'Norm')
# (322, 'reFFT301', 'Phin', 'Freq', 'Norm')
# (323, 'reFFT302', 'Phin', 'Freq', 'Norm')
# (324, 'reFFT303', 'Phin', 'Freq', 'Norm')
# (326, 'reFFT305', 'Phin', 'Freq', 'Norm')
# (327, 'reFFT306', 'Phin', 'Freq', 'Norm')
# (328, 'reFFT307', 'Phin', 'Freq', 'Norm')
# (336, 'reFFT315', 'Phin', 'Freq', 'Norm')
# (341, 'reFFT320', 'Phin', 'Freq', 'Norm')
# (558, 'imFFT024', 'Phin', 'Freq', 'Norm')
# (561, 'imFFT027', 'Phin', 'Freq', 'Norm')
# (565, 'imFFT031', 'Phin', 'Freq', 'Norm')
# (566, 'imFFT032', 'Phin', 'Freq', 'Norm')
# (570, 'imFFT036', 'Phin', 'Freq', 'Norm')
# (572, 'imFFT038', 'Phin', 'Freq', 'Norm')
# (573, 'imFFT039', 'Phin', 'Freq', 'Norm')
# (574, 'imFFT040', 'Phin', 'Freq', 'Norm')
# (575, 'imFFT041', 'Phin', 'Freq', 'Norm')
# (576, 'imFFT042', 'Phin', 'Freq', 'Norm')
# (577, 'imFFT043', 'Phin', 'Freq', 'Norm')
# (578, 'imFFT044', 'Phin', 'Freq', 'Norm')
# (579, 'imFFT045', 'Phin', 'Freq', 'Norm')
# (580, 'imFFT046', 'Phin', 'Freq', 'Norm')
# (581, 'imFFT047', 'Phin', 'Freq', 'Norm')
# (582, 'imFFT048', 'Phin', 'Freq', 'Norm')
# (583, 'imFFT049', 'Phin', 'Freq', 'Norm')
# (585, 'imFFT051', 'Phin', 'Freq', 'Norm')
# (586, 'imFFT052', 'Phin', 'Freq', 'Norm')
# (587, 'imFFT053', 'Phin', 'Freq', 'Norm')
# (588, 'imFFT054', 'Phin', 'Freq', 'Norm')
# (589, 'imFFT055', 'Phin', 'Freq', 'Norm')
# (590, 'imFFT056', 'Phin', 'Freq', 'Norm')
# (594, 'imFFT060', 'Phin', 'Freq', 'Norm')
# (595, 'imFFT061', 'Phin', 'Freq', 'Norm')
# (596, 'imFFT062', 'Phin', 'Freq', 'Norm')
# (601, 'imFFT067', 'Phin', 'Freq', 'Norm')
# (807, 'imFFT273', 'Phin', 'Freq', 'Norm')
# (812, 'imFFT278', 'Phin', 'Freq', 'Norm')
# (813, 'imFFT279', 'Phin', 'Freq', 'Norm')
# (814, 'imFFT280', 'Phin', 'Freq', 'Norm')
# (817, 'imFFT283', 'Phin', 'Freq', 'Norm')
# (818, 'imFFT284', 'Phin', 'Freq', 'Norm')
# (819, 'imFFT285', 'Phin', 'Freq', 'Norm')
# (820, 'imFFT286', 'Phin', 'Freq', 'Norm')
# (823, 'imFFT289', 'Phin', 'Freq', 'Norm')
# (825, 'imFFT291', 'Phin', 'Freq', 'Norm')
# (826, 'imFFT292', 'Phin', 'Freq', 'Norm')
# (827, 'imFFT293', 'Phin', 'Freq', 'Norm')
# (828, 'imFFT294', 'Phin', 'Freq', 'Norm')
# (829, 'imFFT295', 'Phin', 'Freq', 'Norm')
# (830, 'imFFT296', 'Phin', 'Freq', 'Norm')
# (832, 'imFFT298', 'Phin', 'Freq', 'Norm')
# (833, 'imFFT299', 'Phin', 'Freq', 'Norm')
# (834, 'imFFT300', 'Phin', 'Freq', 'Norm')
# (835, 'imFFT301', 'Phin', 'Freq', 'Norm')
# (836, 'imFFT302', 'Phin', 'Freq', 'Norm')
# (837, 'imFFT303', 'Phin', 'Freq', 'Norm')
# (841, 'imFFT307', 'Phin', 'Freq', 'Norm')
# (842, 'imFFT308', 'Phin', 'Freq', 'Norm')
# (843, 'imFFT309', 'Phin', 'Freq', 'Norm')
# (844, 'imFFT310', 'Phin', 'Freq', 'Norm')
# (846, 'imFFT312', 'Phin', 'Freq', 'Norm')
# (847, 'imFFT313', 'Phin', 'Freq', 'Norm')
# (848, 'imFFT314', 'Phin', 'Freq', 'Norm')
# (849, 'imFFT315', 'Phin', 'Freq', 'Norm')
# (851, 'imFFT317', 'Phin', 'Freq', 'Norm')
# (853, 'imFFT319', 'Phin', 'Freq', 'Norm')
# (855, 'imFFT321', 'Phin', 'Freq', 'Norm')
# (857, 'imFFT323', 'Phin', 'Freq', 'Norm')
# (859, 'imFFT325', 'Phin', 'Freq', 'Norm')
# (1045, 'imFFT511', 'Phin', 'Freq', 'Norm')
# (1054, 'sentr', 'Golz', 'Time', 'Norm')
# (1128, 'acrol0071', 'Golz', 'Time', 'Norm')
# (1129, 'acrol0072', 'Golz', 'Time', 'Norm')
# (1130, 'acrol0073', 'Golz', 'Time', 'Norm')
# (1131, 'acrol0074', 'Golz', 'Time', 'Norm')
# (1132, 'acrol0075', 'Golz', 'Time', 'Norm')
# (1133, 'acrol0076', 'Golz', 'Time', 'Norm')
# (1134, 'acrol0077', 'Golz', 'Time', 'Norm')
# (1135, 'acrol0078', 'Golz', 'Time', 'Norm')
# (1136, 'acrol0079', 'Golz', 'Time', 'Norm')
# (1137, 'acrol0080', 'Golz', 'Time', 'Norm')
# (1194, 'acrol0137', 'Golz', 'Time', 'Norm')
# (1198, 'acrol0141', 'Golz', 'Time', 'Norm')
# (1202, 'acrol0145', 'Golz', 'Time', 'Norm')
# (1203, 'acrol0146', 'Golz', 'Time', 'Norm')
# (1204, 'acrol0147', 'Golz', 'Time', 'Norm')
# (1207, 'acrol0150', 'Golz', 'Time', 'Norm')
# (1208, 'acrol0151', 'Golz', 'Time', 'Norm')
# (1223, 'acrol0166', 'Golz', 'Time', 'Norm')
# (1224, 'acrol0167', 'Golz', 'Time', 'Norm')
# (1245, 'acrol0188', 'Golz', 'Time', 'Norm')
# (1246, 'acrol0189', 'Golz', 'Time', 'Norm')
# (1247, 'acrol0190', 'Golz', 'Time', 'Norm')
# (1248, 'acrol0191', 'Golz', 'Time', 'Norm')
# (1250, 'acrol0193', 'Golz', 'Time', 'Norm')
# (1251, 'acrol0194', 'Golz', 'Time', 'Norm')
# (1252, 'acrol0195', 'Golz', 'Time', 'Norm')
# (1254, 'acrol0197', 'Golz', 'Time', 'Norm')
# (1267, 'acrol0210', 'Golz', 'Time', 'Norm')
# (1268, 'acrol0211', 'Golz', 'Time', 'Norm')
# (1269, 'acrol0212', 'Golz', 'Time', 'Norm')
# (1272, 'acrol0215', 'Golz', 'Time', 'Norm')
# (1273, 'acrol0216', 'Golz', 'Time', 'Norm')
# (1278, 'acrol0221', 'Golz', 'Time', 'Norm')
# (1279, 'acrol0222', 'Golz', 'Time', 'Norm')
# (1282, 'acrol0225', 'Golz', 'Time', 'Norm')
# (1283, 'acrol0226', 'Golz', 'Time', 'Norm')
# (1285, 'acrol0228', 'Golz', 'Time', 'Norm')
# (1292, 'acrol0235', 'Golz', 'Time', 'Norm')
# (1293, 'acrol0236', 'Golz', 'Time', 'Norm')
# (1294, 'acrol0237', 'Golz', 'Time', 'Norm')
# (1295, 'acrol0238', 'Golz', 'Time', 'Norm')
# (1296, 'acrol0239', 'Golz', 'Time', 'Norm')
# (1297, 'acrol0240', 'Golz', 'Time', 'Norm')
# (1303, 'acrol0246', 'Golz', 'Time', 'Norm')
# (1308, 'acrol0251', 'Golz', 'Time', 'Norm')
# (1309, 'acrol0252', 'Golz', 'Time', 'Norm')
# (1310, 'acrol0253', 'Golz', 'Time', 'Norm')
# (1311, 'acrol0254', 'Golz', 'Time', 'Norm')
# (1312, 'acrol0255', 'Golz', 'Time', 'Norm')
# (1324, 'acrol0267', 'Golz', 'Time', 'Norm')
# (1326, 'acrol0269', 'Golz', 'Time', 'Norm')
# (1327, 'acrol0270', 'Golz', 'Time', 'Norm')
# (1328, 'acrol0271', 'Golz', 'Time', 'Norm')
# (1333, 'acrol0276', 'Golz', 'Time', 'Norm')
# (1334, 'acrol0277', 'Golz', 'Time', 'Norm')
# (1335, 'acrol0278', 'Golz', 'Time', 'Norm')
# (1339, 'acrol0282', 'Golz', 'Time', 'Norm')
# (1344, 'acrol0287', 'Golz', 'Time', 'Norm')
# (1347, 'acrol0290', 'Golz', 'Time', 'Norm')
# (1348, 'acrol0291', 'Golz', 'Time', 'Norm')
# (1351, 'acrol0294', 'Golz', 'Time', 'Norm')
# (1352, 'acrol0295', 'Golz', 'Time', 'Norm')
# (1353, 'acrol0296', 'Golz', 'Time', 'Norm')
# (1354, 'acrol0297', 'Golz', 'Time', 'Norm')
# (1357, 'acrol0300', 'Golz', 'Time', 'Norm')
# (1358, 'acrol0301', 'Golz', 'Time', 'Norm')
# (1360, 'acrol0303', 'Golz', 'Time', 'Norm')
# (1362, 'acrol0305', 'Golz', 'Time', 'Norm')
# (1363, 'acrol0306', 'Golz', 'Time', 'Norm')
# (1370, 'acrol0313', 'Golz', 'Time', 'Norm')
# (1371, 'acrol0314', 'Golz', 'Time', 'Norm')
# (1372, 'acrol0315', 'Golz', 'Time', 'Norm')
# (1373, 'acrol0316', 'Golz', 'Time', 'Norm')
# (1375, 'acrol0318', 'Golz', 'Time', 'Norm')
# (1376, 'acrol0319', 'Golz', 'Time', 'Norm')
# (1381, 'acrol0324', 'Golz', 'Time', 'Norm')
# (1382, 'acrol0325', 'Golz', 'Time', 'Norm')
# (1383, 'acrol0326', 'Golz', 'Time', 'Norm')
# (1384, 'acrol0327', 'Golz', 'Time', 'Norm')
# (1385, 'acrol0328', 'Golz', 'Time', 'Norm')
# (1386, 'acrol0329', 'Golz', 'Time', 'Norm')
# (1387, 'acrol0330', 'Golz', 'Time', 'Norm')
# (1388, 'acrol0331', 'Golz', 'Time', 'Norm')
# (1394, 'acrol0337', 'Golz', 'Time', 'Norm')
# (1395, 'acrol0338', 'Golz', 'Time', 'Norm')
# (1400, 'acrol0343', 'Golz', 'Time', 'Norm')
# (1401, 'acrol0344', 'Golz', 'Time', 'Norm')
# (1402, 'acrol0345', 'Golz', 'Time', 'Norm')
# (1403, 'acrol0346', 'Golz', 'Time', 'Norm')
# (1404, 'acrol0347', 'Golz', 'Time', 'Norm')
# (1412, 'acrol0355', 'Golz', 'Time', 'Norm')
# (1413, 'acrol0356', 'Golz', 'Time', 'Norm')
# (1414, 'acrol0357', 'Golz', 'Time', 'Norm')
# (1415, 'acrol0358', 'Golz', 'Time', 'Norm')
# (1418, 'acrol0361', 'Golz', 'Time', 'Norm')
# (1419, 'acrol0362', 'Golz', 'Time', 'Norm')
# (1420, 'acrol0363', 'Golz', 'Time', 'Norm')
# (1424, 'acrol0367', 'Golz', 'Time', 'Norm')
# (1425, 'acrol0368', 'Golz', 'Time', 'Norm')
# (1427, 'acrol0370', 'Golz', 'Time', 'Norm')
# (1428, 'acrol0371', 'Golz', 'Time', 'Norm')
# (1429, 'acrol0372', 'Golz', 'Time', 'Norm')
# (1430, 'acrol0373', 'Golz', 'Time', 'Norm')
# (1431, 'acrol0374', 'Golz', 'Time', 'Norm')
# (1433, 'acrol0376', 'Golz', 'Time', 'Norm')
# (1436, 'acrol0379', 'Golz', 'Time', 'Norm')
# (1440, 'acrol0383', 'Golz', 'Time', 'Norm')
# (1444, 'acrol0387', 'Golz', 'Time', 'Norm')
# (1445, 'acrol0388', 'Golz', 'Time', 'Norm')
# (1447, 'acrol0390', 'Golz', 'Time', 'Norm')
# (1448, 'acrol0391', 'Golz', 'Time', 'Norm')
# (1449, 'acrol0392', 'Golz', 'Time', 'Norm')
# (1450, 'acrol0393', 'Golz', 'Time', 'Norm')
# (1451, 'acrol0394', 'Golz', 'Time', 'Norm')
# (1452, 'acrol0395', 'Golz', 'Time', 'Norm')
# (1453, 'acrol0396', 'Golz', 'Time', 'Norm')
# (1454, 'acrol0397', 'Golz', 'Time', 'Norm')
# (1456, 'acrol0399', 'Golz', 'Time', 'Norm')
# (1457, 'acrol0400', 'Golz', 'Time', 'Norm')
# (1458, 'acrol0401', 'Golz', 'Time', 'Norm')
# (1459, 'acrol0402', 'Golz', 'Time', 'Norm')
# (1460, 'acrol0403', 'Golz', 'Time', 'Norm')
# (1461, 'acrol0404', 'Golz', 'Time', 'Norm')
# (1462, 'acrol0405', 'Golz', 'Time', 'Norm')
# (1463, 'acrol0406', 'Golz', 'Time', 'Norm')
# (1464, 'acrol0407', 'Golz', 'Time', 'Norm')
# (1466, 'acrol0409', 'Golz', 'Time', 'Norm')
# (1467, 'acrol0410', 'Golz', 'Time', 'Norm')
# (1468, 'acrol0411', 'Golz', 'Time', 'Norm')
# (1469, 'acrol0412', 'Golz', 'Time', 'Norm')
# (1470, 'acrol0413', 'Golz', 'Time', 'Norm')
# (1471, 'acrol0414', 'Golz', 'Time', 'Norm')
# (1472, 'acrol0415', 'Golz', 'Time', 'Norm')
# (1473, 'acrol0416', 'Golz', 'Time', 'Norm')
# (1474, 'acrol0417', 'Golz', 'Time', 'Norm')
# (1475, 'acrol0418', 'Golz', 'Time', 'Norm')
# (1476, 'acrol0419', 'Golz', 'Time', 'Norm')
# (1477, 'acrol0420', 'Golz', 'Time', 'Norm')
# (1478, 'acrol0421', 'Golz', 'Time', 'Norm')
# (1479, 'acrol0422', 'Golz', 'Time', 'Norm')
# (1480, 'acrol0423', 'Golz', 'Time', 'Norm')
# (1481, 'acrol0424', 'Golz', 'Time', 'Norm')
# (1482, 'acrol0425', 'Golz', 'Time', 'Norm')
# (1483, 'acrol0426', 'Golz', 'Time', 'Norm')
# (1484, 'acrol0427', 'Golz', 'Time', 'Norm')
# (1485, 'acrol0428', 'Golz', 'Time', 'Norm')
# (1486, 'acrol0429', 'Golz', 'Time', 'Norm')
# (1487, 'acrol0430', 'Golz', 'Time', 'Norm')
# (1488, 'acrol0431', 'Golz', 'Time', 'Norm')
# (1489, 'acrol0432', 'Golz', 'Time', 'Norm')
# (1490, 'acrol0433', 'Golz', 'Time', 'Norm')
# (1491, 'acrol0434', 'Golz', 'Time', 'Norm')
# (1492, 'acrol0435', 'Golz', 'Time', 'Norm')
# (1493, 'acrol0436', 'Golz', 'Time', 'Norm')
# (1494, 'acrol0437', 'Golz', 'Time', 'Norm')
# (1495, 'acrol0438', 'Golz', 'Time', 'Norm')
# (1496, 'acrol0439', 'Golz', 'Time', 'Norm')
# (1497, 'acrol0440', 'Golz', 'Time', 'Norm')
# (1498, 'acrol0441', 'Golz', 'Time', 'Norm')
# (1499, 'acrol0442', 'Golz', 'Time', 'Norm')
# (1500, 'acrol0443', 'Golz', 'Time', 'Norm')
# (1501, 'acrol0444', 'Golz', 'Time', 'Norm')
# (1504, 'acrol0447', 'Golz', 'Time', 'Norm')
# (1505, 'acrol0448', 'Golz', 'Time', 'Norm')
# (1507, 'acrol0450', 'Golz', 'Time', 'Norm')
# (1508, 'acrol0451', 'Golz', 'Time', 'Norm')
# (1509, 'acrol0452', 'Golz', 'Time', 'Norm')
# (1510, 'acrol0453', 'Golz', 'Time', 'Norm')
# (1511, 'acrol0454', 'Golz', 'Time', 'Norm')
# (1516, 'acrol0459', 'Golz', 'Time', 'Norm')
# (1517, 'acrol0460', 'Golz', 'Time', 'Norm')
# (1523, 'acrol0466', 'Golz', 'Time', 'Norm')
# (1524, 'acrol0467', 'Golz', 'Time', 'Norm')
# (1525, 'acrol0468', 'Golz', 'Time', 'Norm')
# (1526, 'acrol0469', 'Golz', 'Time', 'Norm')
# (1528, 'acrol0471', 'Golz', 'Time', 'Norm')
# (1529, 'acrol0472', 'Golz', 'Time', 'Norm')
# (1531, 'acrol0474', 'Golz', 'Time', 'Norm')
# (1532, 'acrol0475', 'Golz', 'Time', 'Norm')
# (1533, 'acrol0476', 'Golz', 'Time', 'Norm')
# (1534, 'acrol0477', 'Golz', 'Time', 'Norm')
# (1537, 'acrol0480', 'Golz', 'Time', 'Norm')
# (1540, 'acrol0483', 'Golz', 'Time', 'Norm')
# (1541, 'acrol0484', 'Golz', 'Time', 'Norm')
# (1542, 'acrol0485', 'Golz', 'Time', 'Norm')
# (1543, 'acrol0486', 'Golz', 'Time', 'Norm')
# (1544, 'acrol0487', 'Golz', 'Time', 'Norm')
# (1546, 'acrol0489', 'Golz', 'Time', 'Norm')
# (1554, 'acrol0497', 'Golz', 'Time', 'Norm')
# (1555, 'acrol0498', 'Golz', 'Time', 'Norm')
# (1556, 'acrol0499', 'Golz', 'Time', 'Norm')
# (1558, 'acrol0501', 'Golz', 'Time', 'Norm')
# (1562, 'acrol0505', 'Golz', 'Time', 'Norm')
# (1568, 'acrol0511', 'Golz', 'Time', 'Norm')
# (1569, 'acrol0512', 'Golz', 'Time', 'Norm')
# (1571, 'acrol0514', 'Golz', 'Time', 'Norm')
# (1572, 'acrol0515', 'Golz', 'Time', 'Norm')
# (1573, 'acrol0516', 'Golz', 'Time', 'Norm')
# (1575, 'acrol0518', 'Golz', 'Time', 'Norm')
# (1579, 'acrol0522', 'Golz', 'Time', 'Norm')
# (1582, 'acrol0525', 'Golz', 'Time', 'Norm')
# (1583, 'acrol0526', 'Golz', 'Time', 'Norm')
# (1584, 'acrol0527', 'Golz', 'Time', 'Norm')
# (1585, 'acrol0528', 'Golz', 'Time', 'Norm')
# (1586, 'acrol0529', 'Golz', 'Time', 'Norm')
# (1587, 'acrol0530', 'Golz', 'Time', 'Norm')
# (1588, 'acrol0531', 'Golz', 'Time', 'Norm')
# (1589, 'acrol0532', 'Golz', 'Time', 'Norm')
# (1595, 'acrol0538', 'Golz', 'Time', 'Norm')
# (1596, 'acrol0539', 'Golz', 'Time', 'Norm')
# (1597, 'acrol0540', 'Golz', 'Time', 'Norm')
# (1600, 'acrol0543', 'Golz', 'Time', 'Norm')
# (1601, 'acrol0544', 'Golz', 'Time', 'Norm')
# (1602, 'acrol0545', 'Golz', 'Time', 'Norm')
# (1603, 'acrol0546', 'Golz', 'Time', 'Norm')
# (1604, 'acrol0547', 'Golz', 'Time', 'Norm')
# (1605, 'acrol0548', 'Golz', 'Time', 'Norm')
# (1606, 'acrol0549', 'Golz', 'Time', 'Norm')
# (1607, 'acrol0550', 'Golz', 'Time', 'Norm')
# (1608, 'acrol0551', 'Golz', 'Time', 'Norm')
# (1609, 'acrol0552', 'Golz', 'Time', 'Norm')
# (1611, 'acrol0554', 'Golz', 'Time', 'Norm')
# (1612, 'acrol0555', 'Golz', 'Time', 'Norm')
# (1616, 'acrol0559', 'Golz', 'Time', 'Norm')
# (1629, 'acrol0572', 'Golz', 'Time', 'Norm')
# (1630, 'acrol0573', 'Golz', 'Time', 'Norm')
# (1631, 'acrol0574', 'Golz', 'Time', 'Norm')
# (1662, 'acrol0605', 'Golz', 'Time', 'Norm')
# (1664, 'acrol0607', 'Golz', 'Time', 'Norm')
# (1667, 'acrol0610', 'Golz', 'Time', 'Norm')
# (1668, 'acrol0611', 'Golz', 'Time', 'Norm')
# (1669, 'acrol0612', 'Golz', 'Time', 'Norm')
# (1670, 'acrol0613', 'Golz', 'Time', 'Norm')
# (1674, 'acrol0617', 'Golz', 'Time', 'Norm')
# (1677, 'acrol0620', 'Golz', 'Time', 'Norm')
# (1678, 'acrol0621', 'Golz', 'Time', 'Norm')
# (1681, 'acrol0624', 'Golz', 'Time', 'Norm')
# (1682, 'acrol0625', 'Golz', 'Time', 'Norm')
# (1683, 'acrol0626', 'Golz', 'Time', 'Norm')
# (1684, 'acrol0627', 'Golz', 'Time', 'Norm')
# (1685, 'acrol0628', 'Golz', 'Time', 'Norm')
# (1686, 'acrol0629', 'Golz', 'Time', 'Norm')
# (1687, 'acrol0630', 'Golz', 'Time', 'Norm')
# (1688, 'acrol0631', 'Golz', 'Time', 'Norm')
# (1689, 'acrol0632', 'Golz', 'Time', 'Norm')
# (1690, 'acrol0633', 'Golz', 'Time', 'Norm')
# (1691, 'acrol0634', 'Golz', 'Time', 'Norm')
# (1692, 'acrol0635', 'Golz', 'Time', 'Norm')
# (1693, 'acrol0636', 'Golz', 'Time', 'Norm')
# (1694, 'acrol0637', 'Golz', 'Time', 'Norm')
# (1695, 'acrol0638', 'Golz', 'Time', 'Norm')
# (1696, 'acrol0639', 'Golz', 'Time', 'Norm')
# (1698, 'acrol0641', 'Golz', 'Time', 'Norm')
# (1699, 'acrol0642', 'Golz', 'Time', 'Norm')
# (1700, 'acrol0643', 'Golz', 'Time', 'Norm')
# (1701, 'acrol0644', 'Golz', 'Time', 'Norm')
# (1702, 'acrol0645', 'Golz', 'Time', 'Norm')
# (1703, 'acrol0646', 'Golz', 'Time', 'Norm')
# (1704, 'acrol0647', 'Golz', 'Time', 'Norm')
# (1705, 'acrol0648', 'Golz', 'Time', 'Norm')
# (1706, 'acrol0649', 'Golz', 'Time', 'Norm')
# (1708, 'acrol0651', 'Golz', 'Time', 'Norm')
# (1709, 'acrol0652', 'Golz', 'Time', 'Norm')
# (1710, 'acrol0653', 'Golz', 'Time', 'Norm')
# (1711, 'acrol0654', 'Golz', 'Time', 'Norm')
# (1718, 'acrol0661', 'Golz', 'Time', 'Norm')
# (1719, 'acrol0662', 'Golz', 'Time', 'Norm')
# (1720, 'acrol0663', 'Golz', 'Time', 'Norm')
# (1721, 'acrol0664', 'Golz', 'Time', 'Norm')
# (1722, 'acrol0665', 'Golz', 'Time', 'Norm')
# (1731, 'acrol0674', 'Golz', 'Time', 'Norm')
# (1733, 'acrol0676', 'Golz', 'Time', 'Norm')
# (1734, 'acrol0677', 'Golz', 'Time', 'Norm')
# (1736, 'acrol0679', 'Golz', 'Time', 'Norm')
# (1739, 'acrol0682', 'Golz', 'Time', 'Norm')
# (1741, 'acrol0684', 'Golz', 'Time', 'Norm')
# (1742, 'acrol0685', 'Golz', 'Time', 'Norm')
# (1743, 'acrol0686', 'Golz', 'Time', 'Norm')
# (1746, 'acrol0689', 'Golz', 'Time', 'Norm')
# (1747, 'acrol0690', 'Golz', 'Time', 'Norm')
# (1751, 'acrol0694', 'Golz', 'Time', 'Norm')
# (1752, 'acrol0695', 'Golz', 'Time', 'Norm')
# (1753, 'acrol0696', 'Golz', 'Time', 'Norm')
# (1754, 'acrol0697', 'Golz', 'Time', 'Norm')
# (1755, 'acrol0698', 'Golz', 'Time', 'Norm')
# (1756, 'acrol0699', 'Golz', 'Time', 'Norm')
# (1757, 'acrol0700', 'Golz', 'Time', 'Norm')
# (1758, 'acrol0701', 'Golz', 'Time', 'Norm')
# (1759, 'acrol0702', 'Golz', 'Time', 'Norm')
# (1762, 'acrol0705', 'Golz', 'Time', 'Norm')
# (1763, 'acrol0706', 'Golz', 'Time', 'Norm')
# (1764, 'acrol0707', 'Golz', 'Time', 'Norm')
# (1765, 'acrol0708', 'Golz', 'Time', 'Norm')
# (1766, 'acrol0709', 'Golz', 'Time', 'Norm')
# (1767, 'acrol0710', 'Golz', 'Time', 'Norm')
# (1768, 'acrol0711', 'Golz', 'Time', 'Norm')
# (1769, 'acrol0712', 'Golz', 'Time', 'Norm')
# (1771, 'acrol0714', 'Golz', 'Time', 'Norm')
# (1772, 'acrol0715', 'Golz', 'Time', 'Norm')
# (1773, 'acrol0716', 'Golz', 'Time', 'Norm')
# (1774, 'acrol0717', 'Golz', 'Time', 'Norm')
# (1775, 'acrol0718', 'Golz', 'Time', 'Norm')
# (1776, 'acrol0719', 'Golz', 'Time', 'Norm')
# (1777, 'acrol0720', 'Golz', 'Time', 'Norm')
# (1778, 'acrol0721', 'Golz', 'Time', 'Norm')
# (1779, 'acrol0722', 'Golz', 'Time', 'Norm')
# (1780, 'acrol0723', 'Golz', 'Time', 'Norm')
# (1782, 'acrol0725', 'Golz', 'Time', 'Norm')
# (1783, 'acrol0726', 'Golz', 'Time', 'Norm')
# (1784, 'acrol0727', 'Golz', 'Time', 'Norm')
# (1785, 'acrol0728', 'Golz', 'Time', 'Norm')
# (1786, 'acrol0729', 'Golz', 'Time', 'Norm')
# (1787, 'acrol0730', 'Golz', 'Time', 'Norm')
# (1788, 'acrol0731', 'Golz', 'Time', 'Norm')
# (1789, 'acrol0732', 'Golz', 'Time', 'Norm')
# (1790, 'acrol0733', 'Golz', 'Time', 'Norm')
# (1792, 'acrol0735', 'Golz', 'Time', 'Norm')
# (1797, 'acrol0740', 'Golz', 'Time', 'Norm')
# (1798, 'acrol0741', 'Golz', 'Time', 'Norm')
# (1800, 'acrol0743', 'Golz', 'Time', 'Norm')
# (1801, 'acrol0744', 'Golz', 'Time', 'Norm')
# (1803, 'acrol0746', 'Golz', 'Time', 'Norm')
# (1804, 'acrol0747', 'Golz', 'Time', 'Norm')
# (1805, 'acrol0748', 'Golz', 'Time', 'Norm')
# (1806, 'acrol0749', 'Golz', 'Time', 'Norm')
# (1807, 'acrol0750', 'Golz', 'Time', 'Norm')
# (1808, 'acrol0751', 'Golz', 'Time', 'Norm')
# (1809, 'acrol0752', 'Golz', 'Time', 'Norm')
# (1810, 'acrol0753', 'Golz', 'Time', 'Norm')
# (1811, 'acrol0754', 'Golz', 'Time', 'Norm')
# (1812, 'acrol0755', 'Golz', 'Time', 'Norm')
# (1815, 'acrol0758', 'Golz', 'Time', 'Norm')
# (1816, 'acrol0759', 'Golz', 'Time', 'Norm')
# (1817, 'acrol0760', 'Golz', 'Time', 'Norm')
# (1818, 'acrol0761', 'Golz', 'Time', 'Norm')
# (1819, 'acrol0762', 'Golz', 'Time', 'Norm')
# (1824, 'acrol0767', 'Golz', 'Time', 'Norm')
# (1825, 'acrol0768', 'Golz', 'Time', 'Norm')
# (1826, 'acrol0769', 'Golz', 'Time', 'Norm')
# (1829, 'acrol0772', 'Golz', 'Time', 'Norm')
# (1830, 'acrol0773', 'Golz', 'Time', 'Norm')
# (1831, 'acrol0774', 'Golz', 'Time', 'Norm')
# (1832, 'acrol0775', 'Golz', 'Time', 'Norm')
# (1833, 'acrol0776', 'Golz', 'Time', 'Norm')
# (1834, 'acrol0777', 'Golz', 'Time', 'Norm')
# (1835, 'acrol0778', 'Golz', 'Time', 'Norm')
# (1836, 'acrol0779', 'Golz', 'Time', 'Norm')
# (1837, 'acrol0780', 'Golz', 'Time', 'Norm')
# (1838, 'acrol0781', 'Golz', 'Time', 'Norm')
# (1839, 'acrol0782', 'Golz', 'Time', 'Norm')
# (1841, 'acrol0784', 'Golz', 'Time', 'Norm')
# (1843, 'acrol0786', 'Golz', 'Time', 'Norm')
# (1844, 'acrol0787', 'Golz', 'Time', 'Norm')
# (1845, 'acrol0788', 'Golz', 'Time', 'Norm')
# (1846, 'acrol0789', 'Golz', 'Time', 'Norm')
# (1847, 'acrol0790', 'Golz', 'Time', 'Norm')
# (1848, 'acrol0791', 'Golz', 'Time', 'Norm')
# (1849, 'acrol0792', 'Golz', 'Time', 'Norm')
# (1850, 'acrol0793', 'Golz', 'Time', 'Norm')
# (1851, 'acrol0794', 'Golz', 'Time', 'Norm')
# (1852, 'acrol0795', 'Golz', 'Time', 'Norm')
# (1853, 'acrol0796', 'Golz', 'Time', 'Norm')
# (1855, 'acrol0798', 'Golz', 'Time', 'Norm')
# (1856, 'acrol0799', 'Golz', 'Time', 'Norm')
# (1857, 'acrol0800', 'Golz', 'Time', 'Norm')
# (1858, 'acrol0801', 'Golz', 'Time', 'Norm')
# (1859, 'acrol0802', 'Golz', 'Time', 'Norm')
# (1860, 'acrol0803', 'Golz', 'Time', 'Norm')
# (1870, 'acrol0813', 'Golz', 'Time', 'Norm')
# (1872, 'acrol0815', 'Golz', 'Time', 'Norm')
# (1873, 'acrol0816', 'Golz', 'Time', 'Norm')
# (1874, 'acrol0817', 'Golz', 'Time', 'Norm')
# (1875, 'acrol0818', 'Golz', 'Time', 'Norm')
# (1876, 'acrol0819', 'Golz', 'Time', 'Norm')
# (1877, 'acrol0820', 'Golz', 'Time', 'Norm')
# (1880, 'acrol0823', 'Golz', 'Time', 'Norm')
# (1881, 'acrol0824', 'Golz', 'Time', 'Norm')
# (1882, 'acrol0825', 'Golz', 'Time', 'Norm')
# (1883, 'acrol0826', 'Golz', 'Time', 'Norm')
# (1884, 'acrol0827', 'Golz', 'Time', 'Norm')
# (1885, 'acrol0828', 'Golz', 'Time', 'Norm')
# (1886, 'acrol0829', 'Golz', 'Time', 'Norm')
# (1887, 'acrol0830', 'Golz', 'Time', 'Norm')
# (1892, 'acrol0835', 'Golz', 'Time', 'Norm')
# (1896, 'acrol0839', 'Golz', 'Time', 'Norm')
# (1899, 'acrol0842', 'Golz', 'Time', 'Norm')
# (1900, 'acrol0843', 'Golz', 'Time', 'Norm')
# (1901, 'acrol0844', 'Golz', 'Time', 'Norm')
# (1903, 'acrol0846', 'Golz', 'Time', 'Norm')
# (1904, 'acrol0847', 'Golz', 'Time', 'Norm')
# (1906, 'acrol0849', 'Golz', 'Time', 'Norm')
# (1907, 'acrol0850', 'Golz', 'Time', 'Norm')
# (1908, 'acrol0851', 'Golz', 'Time', 'Norm')
# (1909, 'acrol0852', 'Golz', 'Time', 'Norm')
# (1910, 'acrol0853', 'Golz', 'Time', 'Norm')
# (1916, 'acrol0859', 'Golz', 'Time', 'Norm')
# (1922, 'acrol0865', 'Golz', 'Time', 'Norm')
# (1927, 'acrol0870', 'Golz', 'Time', 'Norm')
# (1928, 'acrol0871', 'Golz', 'Time', 'Norm')
# (1930, 'acrol0873', 'Golz', 'Time', 'Norm')
# (1932, 'acrol0875', 'Golz', 'Time', 'Norm')
# (1938, 'acrol0881', 'Golz', 'Time', 'Norm')
# (1939, 'acrol0882', 'Golz', 'Time', 'Norm')
# (1940, 'acrol0883', 'Golz', 'Time', 'Norm')
# (1941, 'acrol0884', 'Golz', 'Time', 'Norm')
# (1942, 'acrol0885', 'Golz', 'Time', 'Norm')
# (1943, 'acrol0886', 'Golz', 'Time', 'Norm')
# (1944, 'acrol0887', 'Golz', 'Time', 'Norm')
# (1945, 'acrol0888', 'Golz', 'Time', 'Norm')
# (1948, 'acrol0891', 'Golz', 'Time', 'Norm')
# (1949, 'acrol0892', 'Golz', 'Time', 'Norm')
# (1950, 'acrol0893', 'Golz', 'Time', 'Norm')
# (1951, 'acrol0894', 'Golz', 'Time', 'Norm')
# (1952, 'acrol0895', 'Golz', 'Time', 'Norm')
# (1953, 'acrol0896', 'Golz', 'Time', 'Norm')
# (1954, 'acrol0897', 'Golz', 'Time', 'Norm')
# (1955, 'acrol0898', 'Golz', 'Time', 'Norm')
# (1956, 'acrol0899', 'Golz', 'Time', 'Norm')
# (1957, 'acrol0900', 'Golz', 'Time', 'Norm')
# (1958, 'acrol0901', 'Golz', 'Time', 'Norm')
# (1959, 'acrol0902', 'Golz', 'Time', 'Norm')
# (1966, 'acrol0909', 'Golz', 'Time', 'Norm')
# (1976, 'acrol0919', 'Golz', 'Time', 'Norm')
# (1985, 'acrol0928', 'Golz', 'Time', 'Norm')
# (1986, 'acrol0929', 'Golz', 'Time', 'Norm')
# (1988, 'acrol0931', 'Golz', 'Time', 'Norm')
# (1989, 'acrol0932', 'Golz', 'Time', 'Norm')
# (1990, 'acrol0933', 'Golz', 'Time', 'Norm')
# (2003, 'acrol0946', 'Golz', 'Time', 'Norm')
# (2005, 'acrol0948', 'Golz', 'Time', 'Norm')
# (2007, 'acrol0950', 'Golz', 'Time', 'Norm')
# (2008, 'acrol0951', 'Golz', 'Time', 'Norm')
# (2009, 'acrol0952', 'Golz', 'Time', 'Norm')
# (2013, 'acrol0956', 'Golz', 'Time', 'Norm')
# (2015, 'acrol0958', 'Golz', 'Time', 'Norm')
# (2016, 'acrol0959', 'Golz', 'Time', 'Norm')
# (2019, 'acrol0962', 'Golz', 'Time', 'Norm')
# (2020, 'acrol0963', 'Golz', 'Time', 'Norm')
# (2021, 'acrol0964', 'Golz', 'Time', 'Norm')
# (2022, 'acrol0965', 'Golz', 'Time', 'Norm')
# (2024, 'acrol0967', 'Golz', 'Time', 'Norm')
# (2025, 'acrol0968', 'Golz', 'Time', 'Norm')
# (2026, 'acrol0969', 'Golz', 'Time', 'Norm')
# (2027, 'acrol0970', 'Golz', 'Time', 'Norm')
# (2028, 'acrol0971', 'Golz', 'Time', 'Norm')
# (2029, 'acrol0972', 'Golz', 'Time', 'Norm')
# (2030, 'acrol0973', 'Golz', 'Time', 'Norm')
# (2034, 'acrol0977', 'Golz', 'Time', 'Norm')
# (2037, 'acrol0980', 'Golz', 'Time', 'Norm')
# (2041, 'acrol0984', 'Golz', 'Time', 'Norm')
# (2043, 'acrol0986', 'Golz', 'Time', 'Norm')
# (2051, 'acrol0994', 'Golz', 'Time', 'Norm')
# (2052, 'acrol0995', 'Golz', 'Time', 'Norm')
# (2053, 'acrol0996', 'Golz', 'Time', 'Norm')
# (2054, 'acrol0997', 'Golz', 'Time', 'Norm')
# (2055, 'acrol0998', 'Golz', 'Time', 'Norm')
# (2056, 'acrol0999', 'Golz', 'Time', 'Norm')
# (2057, 'acrol1000', 'Golz', 'Time', 'Norm')
# (2058, 'acrol1001', 'Golz', 'Time', 'Norm')
# (2073, 'acrol1016', 'Golz', 'Time', 'Norm')
# (2078, 'acrol1021', 'Golz', 'Time', 'Norm')
# (2080, 'acrol1023', 'Golz', 'Time', 'Norm')
# (2139, 'amFFT058', 'Golz', 'Freq', 'Norm')
# (2140, 'amFFT059', 'Golz', 'Freq', 'Norm')
# (2141, 'amFFT060', 'Golz', 'Freq', 'Norm')
# (2142, 'amFFT061', 'Golz', 'Freq', 'Norm')
# (2143, 'amFFT062', 'Golz', 'Freq', 'Norm')
# (2147, 'amFFT066', 'Golz', 'Freq', 'Norm')
# (2148, 'amFFT067', 'Golz', 'Freq', 'Norm')
# (2150, 'amFFT069', 'Golz', 'Freq', 'Norm')
# (2390, 'amFFT309', 'Golz', 'Freq', 'Norm')
# (2392, 'amFFT311', 'Golz', 'Freq', 'Norm')
# (2398, 'amFFT317', 'Golz', 'Freq', 'Norm')
# (2403, 'amFFT322', 'Golz', 'Freq', 'Norm')
# (2406, 'amFFT325', 'Golz', 'Freq', 'Norm')
# (2408, 'amFFT327', 'Golz', 'Freq', 'Norm')
# (2410, 'amFFT329', 'Golz', 'Freq', 'Norm')
# (2411, 'amFFT330', 'Golz', 'Freq', 'Norm')
# (2412, 'amFFT331', 'Golz', 'Freq', 'Norm')
# (2413, 'amFFT332', 'Golz', 'Freq', 'Norm')
# (2415, 'amFFT334', 'Golz', 'Freq', 'Norm')
# (2416, 'amFFT335', 'Golz', 'Freq', 'Norm')
# (2417, 'amFFT336', 'Golz', 'Freq', 'Norm')
# (2418, 'amFFT337', 'Golz', 'Freq', 'Norm')
# (2419, 'amFFT338', 'Golz', 'Freq', 'Norm')
# (2420, 'amFFT339', 'Golz', 'Freq', 'Norm')
# (2422, 'amFFT341', 'Golz', 'Freq', 'Norm')
# (2423, 'amFFT342', 'Golz', 'Freq', 'Norm')
# (2424, 'amFFT343', 'Golz', 'Freq', 'Norm')
# (2425, 'amFFT344', 'Golz', 'Freq', 'Norm')
# (2426, 'amFFT345', 'Golz', 'Freq', 'Norm')
# (2428, 'amFFT347', 'Golz', 'Freq', 'Norm')
# (2429, 'amFFT348', 'Golz', 'Freq', 'Norm')
# (2430, 'amFFT349', 'Golz', 'Freq', 'Norm')
# (2431, 'amFFT350', 'Golz', 'Freq', 'Norm')
# (2432, 'amFFT351', 'Golz', 'Freq', 'Norm')
# (2433, 'amFFT352', 'Golz', 'Freq', 'Norm')
# (2434, 'amFFT353', 'Golz', 'Freq', 'Norm')
# (2435, 'amFFT354', 'Golz', 'Freq', 'Norm')
# (2436, 'amFFT355', 'Golz', 'Freq', 'Norm')
# (2437, 'amFFT356', 'Golz', 'Freq', 'Norm')
# (2438, 'amFFT357', 'Golz', 'Freq', 'Norm')
# (2439, 'amFFT358', 'Golz', 'Freq', 'Norm')
# (2440, 'amFFT359', 'Golz', 'Freq', 'Norm')
# (2441, 'amFFT360', 'Golz', 'Freq', 'Norm')
# (2442, 'amFFT361', 'Golz', 'Freq', 'Norm')
# (2443, 'amFFT362', 'Golz', 'Freq', 'Norm')
# (2444, 'amFFT363', 'Golz', 'Freq', 'Norm')
# (2445, 'amFFT364', 'Golz', 'Freq', 'Norm')
# (2446, 'amFFT365', 'Golz', 'Freq', 'Norm')
# (2447, 'amFFT366', 'Golz', 'Freq', 'Norm')
# (2448, 'amFFT367', 'Golz', 'Freq', 'Norm')
# (2449, 'amFFT368', 'Golz', 'Freq', 'Norm')
# (2450, 'amFFT369', 'Golz', 'Freq', 'Norm')
# (2451, 'amFFT370', 'Golz', 'Freq', 'Norm')
# (2452, 'amFFT371', 'Golz', 'Freq', 'Norm')
# (2453, 'amFFT372', 'Golz', 'Freq', 'Norm')
# (2454, 'amFFT373', 'Golz', 'Freq', 'Norm')
# (2455, 'amFFT374', 'Golz', 'Freq', 'Norm')
# (2456, 'amFFT375', 'Golz', 'Freq', 'Norm')
# (2457, 'amFFT376', 'Golz', 'Freq', 'Norm')
# (2458, 'amFFT377', 'Golz', 'Freq', 'Norm')
# (2459, 'amFFT378', 'Golz', 'Freq', 'Norm')
# (2460, 'amFFT379', 'Golz', 'Freq', 'Norm')
# (2461, 'amFFT380', 'Golz', 'Freq', 'Norm')
# (2462, 'amFFT381', 'Golz', 'Freq', 'Norm')
# (2463, 'amFFT382', 'Golz', 'Freq', 'Norm')
# (2464, 'amFFT383', 'Golz', 'Freq', 'Norm')
# (2465, 'amFFT384', 'Golz', 'Freq', 'Norm')
# (2466, 'amFFT385', 'Golz', 'Freq', 'Norm')
# (2467, 'amFFT386', 'Golz', 'Freq', 'Norm')
# (2468, 'amFFT387', 'Golz', 'Freq', 'Norm')
# (2469, 'amFFT388', 'Golz', 'Freq', 'Norm')
# (2470, 'amFFT389', 'Golz', 'Freq', 'Norm')
# (2471, 'amFFT390', 'Golz', 'Freq', 'Norm')
# (2472, 'amFFT391', 'Golz', 'Freq', 'Norm')
# (2473, 'amFFT392', 'Golz', 'Freq', 'Norm')
# (2474, 'amFFT393', 'Golz', 'Freq', 'Norm')
# (2475, 'amFFT394', 'Golz', 'Freq', 'Norm')
# (2476, 'amFFT395', 'Golz', 'Freq', 'Norm')
# (2477, 'amFFT396', 'Golz', 'Freq', 'Norm')
# (2478, 'amFFT397', 'Golz', 'Freq', 'Norm')
# (2479, 'amFFT398', 'Golz', 'Freq', 'Norm')
# (2480, 'amFFT399', 'Golz', 'Freq', 'Norm')
# (2481, 'amFFT400', 'Golz', 'Freq', 'Norm')
# (2482, 'amFFT401', 'Golz', 'Freq', 'Norm')
# (2483, 'amFFT402', 'Golz', 'Freq', 'Norm')
# (2484, 'amFFT403', 'Golz', 'Freq', 'Norm')
# (2485, 'amFFT404', 'Golz', 'Freq', 'Norm')
# (2486, 'amFFT405', 'Golz', 'Freq', 'Norm')
# (2487, 'amFFT406', 'Golz', 'Freq', 'Norm')
# (2488, 'amFFT407', 'Golz', 'Freq', 'Norm')
# (2489, 'amFFT408', 'Golz', 'Freq', 'Norm')
# (2490, 'amFFT409', 'Golz', 'Freq', 'Norm')
# (2491, 'amFFT410', 'Golz', 'Freq', 'Norm')
# (2492, 'amFFT411', 'Golz', 'Freq', 'Norm')
# (2493, 'amFFT412', 'Golz', 'Freq', 'Norm')
# (2494, 'amFFT413', 'Golz', 'Freq', 'Norm')
# (2495, 'amFFT414', 'Golz', 'Freq', 'Norm')
# (2496, 'amFFT415', 'Golz', 'Freq', 'Norm')
# (2497, 'amFFT416', 'Golz', 'Freq', 'Norm')
# (2498, 'amFFT417', 'Golz', 'Freq', 'Norm')
# (2499, 'amFFT418', 'Golz', 'Freq', 'Norm')
# (2500, 'amFFT419', 'Golz', 'Freq', 'Norm')
# (2501, 'amFFT420', 'Golz', 'Freq', 'Norm')
# (2503, 'amFFT422', 'Golz', 'Freq', 'Norm')
# (2504, 'amFFT423', 'Golz', 'Freq', 'Norm')
# (2505, 'amFFT424', 'Golz', 'Freq', 'Norm')
# (2506, 'amFFT425', 'Golz', 'Freq', 'Norm')
# (2507, 'amFFT426', 'Golz', 'Freq', 'Norm')
# (2508, 'amFFT427', 'Golz', 'Freq', 'Norm')
# (2509, 'amFFT428', 'Golz', 'Freq', 'Norm')
# (2510, 'amFFT429', 'Golz', 'Freq', 'Norm')
# (2511, 'amFFT430', 'Golz', 'Freq', 'Norm')
# (2512, 'amFFT431', 'Golz', 'Freq', 'Norm')
# (2514, 'amFFT433', 'Golz', 'Freq', 'Norm')
# (2515, 'amFFT434', 'Golz', 'Freq', 'Norm')
# (2516, 'amFFT435', 'Golz', 'Freq', 'Norm')
# (2517, 'amFFT436', 'Golz', 'Freq', 'Norm')
# (2518, 'amFFT437', 'Golz', 'Freq', 'Norm')
# (2519, 'amFFT438', 'Golz', 'Freq', 'Norm')
# (2520, 'amFFT439', 'Golz', 'Freq', 'Norm')
# (2521, 'amFFT440', 'Golz', 'Freq', 'Norm')
# (2522, 'amFFT441', 'Golz', 'Freq', 'Norm')
# (2523, 'amFFT442', 'Golz', 'Freq', 'Norm')
# (2524, 'amFFT443', 'Golz', 'Freq', 'Norm')
# (2525, 'amFFT444', 'Golz', 'Freq', 'Norm')
# (2526, 'amFFT445', 'Golz', 'Freq', 'Norm')
# (2527, 'amFFT446', 'Golz', 'Freq', 'Norm')
# (2528, 'amFFT447', 'Golz', 'Freq', 'Norm')
# (2529, 'amFFT448', 'Golz', 'Freq', 'Norm')
# (2530, 'amFFT449', 'Golz', 'Freq', 'Norm')
# (2531, 'amFFT450', 'Golz', 'Freq', 'Norm')
# (2532, 'amFFT451', 'Golz', 'Freq', 'Norm')
# (2533, 'amFFT452', 'Golz', 'Freq', 'Norm')
# (2534, 'amFFT453', 'Golz', 'Freq', 'Norm')
# (2535, 'amFFT454', 'Golz', 'Freq', 'Norm')
# (2536, 'amFFT455', 'Golz', 'Freq', 'Norm')
# (2537, 'amFFT456', 'Golz', 'Freq', 'Norm')
# (2538, 'amFFT457', 'Golz', 'Freq', 'Norm')
# (2539, 'amFFT458', 'Golz', 'Freq', 'Norm')
# (2541, 'amFFT460', 'Golz', 'Freq', 'Norm')
# (2543, 'amFFT462', 'Golz', 'Freq', 'Norm')
# (2544, 'amFFT463', 'Golz', 'Freq', 'Norm')
# (2545, 'amFFT464', 'Golz', 'Freq', 'Norm')
# (2547, 'amFFT466', 'Golz', 'Freq', 'Norm')
# (2548, 'amFFT467', 'Golz', 'Freq', 'Norm')
# (2549, 'amFFT468', 'Golz', 'Freq', 'Norm')
# (2552, 'amFFT471', 'Golz', 'Freq', 'Norm')
# (2553, 'amFFT472', 'Golz', 'Freq', 'Norm')
# (2554, 'amFFT473', 'Golz', 'Freq', 'Norm')
# (2555, 'amFFT474', 'Golz', 'Freq', 'Norm')
# (2556, 'amFFT475', 'Golz', 'Freq', 'Norm')
# (2557, 'amFFT476', 'Golz', 'Freq', 'Norm')
# (2558, 'amFFT477', 'Golz', 'Freq', 'Norm')
# (2559, 'amFFT478', 'Golz', 'Freq', 'Norm')
# (2560, 'amFFT479', 'Golz', 'Freq', 'Norm')
# (2561, 'amFFT480', 'Golz', 'Freq', 'Norm')
# (2562, 'amFFT481', 'Golz', 'Freq', 'Norm')
# (2563, 'amFFT482', 'Golz', 'Freq', 'Norm')
# (2564, 'amFFT483', 'Golz', 'Freq', 'Norm')
# (2565, 'amFFT484', 'Golz', 'Freq', 'Norm')
# (2566, 'amFFT485', 'Golz', 'Freq', 'Norm')
# (2567, 'amFFT486', 'Golz', 'Freq', 'Norm')
# (2568, 'amFFT487', 'Golz', 'Freq', 'Norm')
# (2569, 'amFFT488', 'Golz', 'Freq', 'Norm')
# (2570, 'amFFT489', 'Golz', 'Freq', 'Norm')
# (2571, 'amFFT490', 'Golz', 'Freq', 'Norm')
# (2572, 'amFFT491', 'Golz', 'Freq', 'Norm')
# (2573, 'amFFT492', 'Golz', 'Freq', 'Norm')
# (2574, 'amFFT493', 'Golz', 'Freq', 'Norm')
# (2575, 'amFFT494', 'Golz', 'Freq', 'Norm')
# (2576, 'amFFT495', 'Golz', 'Freq', 'Norm')
# (2577, 'amFFT496', 'Golz', 'Freq', 'Norm')
# (2578, 'amFFT497', 'Golz', 'Freq', 'Norm')
# (2579, 'amFFT498', 'Golz', 'Freq', 'Norm')
# (2580, 'amFFT499', 'Golz', 'Freq', 'Norm')
# (2581, 'amFFT500', 'Golz', 'Freq', 'Norm')
# (2582, 'amFFT501', 'Golz', 'Freq', 'Norm')
# (2583, 'amFFT502', 'Golz', 'Freq', 'Norm')
# (2584, 'amFFT503', 'Golz', 'Freq', 'Norm')
# (2586, 'amFFT505', 'Golz', 'Freq', 'Norm')
# (2587, 'amFFT506', 'Golz', 'Freq', 'Norm')
# (2588, 'amFFT507', 'Golz', 'Freq', 'Norm')
# (2589, 'amFFT508', 'Golz', 'Freq', 'Norm')
# (2590, 'amFFT509', 'Golz', 'Freq', 'Norm')
# (2591, 'amFFT510', 'Golz', 'Freq', 'Norm')
# (2592, 'amFFT511', 'Golz', 'Freq', 'Norm')
# (2593, 'amFFT512', 'Golz', 'Freq', 'Norm')
# (2652, 'phFFT058', 'Golz', 'Freq', 'Norm')
# (2653, 'phFFT059', 'Golz', 'Freq', 'Norm')
# (2654, 'phFFT060', 'Golz', 'Freq', 'Norm')
# (2655, 'phFFT061', 'Golz', 'Freq', 'Norm')
# (2656, 'phFFT062', 'Golz', 'Freq', 'Norm')
# (2660, 'phFFT066', 'Golz', 'Freq', 'Norm')
# (2661, 'phFFT067', 'Golz', 'Freq', 'Norm')
# (2663, 'phFFT069', 'Golz', 'Freq', 'Norm')
# (2903, 'phFFT309', 'Golz', 'Freq', 'Norm')
# (2905, 'phFFT311', 'Golz', 'Freq', 'Norm')
# (2911, 'phFFT317', 'Golz', 'Freq', 'Norm')
# (2916, 'phFFT322', 'Golz', 'Freq', 'Norm')
# (2919, 'phFFT325', 'Golz', 'Freq', 'Norm')
# (2921, 'phFFT327', 'Golz', 'Freq', 'Norm')
# (2923, 'phFFT329', 'Golz', 'Freq', 'Norm')
# (2924, 'phFFT330', 'Golz', 'Freq', 'Norm')
# (2925, 'phFFT331', 'Golz', 'Freq', 'Norm')
# (2926, 'phFFT332', 'Golz', 'Freq', 'Norm')
# (2928, 'phFFT334', 'Golz', 'Freq', 'Norm')
# (2929, 'phFFT335', 'Golz', 'Freq', 'Norm')
# (2930, 'phFFT336', 'Golz', 'Freq', 'Norm')
# (2931, 'phFFT337', 'Golz', 'Freq', 'Norm')
# (2932, 'phFFT338', 'Golz', 'Freq', 'Norm')
# (2933, 'phFFT339', 'Golz', 'Freq', 'Norm')
# (2935, 'phFFT341', 'Golz', 'Freq', 'Norm')
# (2936, 'phFFT342', 'Golz', 'Freq', 'Norm')
# (2937, 'phFFT343', 'Golz', 'Freq', 'Norm')
# (2938, 'phFFT344', 'Golz', 'Freq', 'Norm')
# (2939, 'phFFT345', 'Golz', 'Freq', 'Norm')
# (2941, 'phFFT347', 'Golz', 'Freq', 'Norm')
# (2942, 'phFFT348', 'Golz', 'Freq', 'Norm')
# (2943, 'phFFT349', 'Golz', 'Freq', 'Norm')
# (2944, 'phFFT350', 'Golz', 'Freq', 'Norm')
# (2945, 'phFFT351', 'Golz', 'Freq', 'Norm')
# (2946, 'phFFT352', 'Golz', 'Freq', 'Norm')
# (2947, 'phFFT353', 'Golz', 'Freq', 'Norm')
# (2948, 'phFFT354', 'Golz', 'Freq', 'Norm')
# (2949, 'phFFT355', 'Golz', 'Freq', 'Norm')
# (2950, 'phFFT356', 'Golz', 'Freq', 'Norm')
# (2951, 'phFFT357', 'Golz', 'Freq', 'Norm')
# (2952, 'phFFT358', 'Golz', 'Freq', 'Norm')
# (2953, 'phFFT359', 'Golz', 'Freq', 'Norm')
# (2954, 'phFFT360', 'Golz', 'Freq', 'Norm')
# (2955, 'phFFT361', 'Golz', 'Freq', 'Norm')
# (2956, 'phFFT362', 'Golz', 'Freq', 'Norm')
# (2957, 'phFFT363', 'Golz', 'Freq', 'Norm')
# (2958, 'phFFT364', 'Golz', 'Freq', 'Norm')
# (2959, 'phFFT365', 'Golz', 'Freq', 'Norm')
# (2960, 'phFFT366', 'Golz', 'Freq', 'Norm')
# (2961, 'phFFT367', 'Golz', 'Freq', 'Norm')
# (2962, 'phFFT368', 'Golz', 'Freq', 'Norm')
# (2963, 'phFFT369', 'Golz', 'Freq', 'Norm')
# (2964, 'phFFT370', 'Golz', 'Freq', 'Norm')
# (2965, 'phFFT371', 'Golz', 'Freq', 'Norm')
# (2966, 'phFFT372', 'Golz', 'Freq', 'Norm')
# (2967, 'phFFT373', 'Golz', 'Freq', 'Norm')
# (2968, 'phFFT374', 'Golz', 'Freq', 'Norm')
# (2969, 'phFFT375', 'Golz', 'Freq', 'Norm')
# (2970, 'phFFT376', 'Golz', 'Freq', 'Norm')
# (2971, 'phFFT377', 'Golz', 'Freq', 'Norm')
# (2972, 'phFFT378', 'Golz', 'Freq', 'Norm')
# (2973, 'phFFT379', 'Golz', 'Freq', 'Norm')
# (2974, 'phFFT380', 'Golz', 'Freq', 'Norm')
# (2975, 'phFFT381', 'Golz', 'Freq', 'Norm')
# (2976, 'phFFT382', 'Golz', 'Freq', 'Norm')
# (2977, 'phFFT383', 'Golz', 'Freq', 'Norm')
# (2978, 'phFFT384', 'Golz', 'Freq', 'Norm')
# (2979, 'phFFT385', 'Golz', 'Freq', 'Norm')
# (2980, 'phFFT386', 'Golz', 'Freq', 'Norm')
# (2981, 'phFFT387', 'Golz', 'Freq', 'Norm')
# (2982, 'phFFT388', 'Golz', 'Freq', 'Norm')
# (2983, 'phFFT389', 'Golz', 'Freq', 'Norm')
# (2984, 'phFFT390', 'Golz', 'Freq', 'Norm')
# (2985, 'phFFT391', 'Golz', 'Freq', 'Norm')
# (2986, 'phFFT392', 'Golz', 'Freq', 'Norm')
# (2987, 'phFFT393', 'Golz', 'Freq', 'Norm')
# (2988, 'phFFT394', 'Golz', 'Freq', 'Norm')
# (2989, 'phFFT395', 'Golz', 'Freq', 'Norm')
# (2990, 'phFFT396', 'Golz', 'Freq', 'Norm')
# (2991, 'phFFT397', 'Golz', 'Freq', 'Norm')
# (2992, 'phFFT398', 'Golz', 'Freq', 'Norm')
# (2993, 'phFFT399', 'Golz', 'Freq', 'Norm')
# (2994, 'phFFT400', 'Golz', 'Freq', 'Norm')
# (2995, 'phFFT401', 'Golz', 'Freq', 'Norm')
# (2996, 'phFFT402', 'Golz', 'Freq', 'Norm')
# (2997, 'phFFT403', 'Golz', 'Freq', 'Norm')
# (2998, 'phFFT404', 'Golz', 'Freq', 'Norm')
# (2999, 'phFFT405', 'Golz', 'Freq', 'Norm')
# (3000, 'phFFT406', 'Golz', 'Freq', 'Norm')
# (3001, 'phFFT407', 'Golz', 'Freq', 'Norm')
# (3002, 'phFFT408', 'Golz', 'Freq', 'Norm')
# (3003, 'phFFT409', 'Golz', 'Freq', 'Norm')
# (3004, 'phFFT410', 'Golz', 'Freq', 'Norm')
# (3005, 'phFFT411', 'Golz', 'Freq', 'Norm')
# (3006, 'phFFT412', 'Golz', 'Freq', 'Norm')
# (3007, 'phFFT413', 'Golz', 'Freq', 'Norm')
# (3008, 'phFFT414', 'Golz', 'Freq', 'Norm')
# (3009, 'phFFT415', 'Golz', 'Freq', 'Norm')
# (3010, 'phFFT416', 'Golz', 'Freq', 'Norm')
# (3011, 'phFFT417', 'Golz', 'Freq', 'Norm')
# (3012, 'phFFT418', 'Golz', 'Freq', 'Norm')
# (3013, 'phFFT419', 'Golz', 'Freq', 'Norm')
# (3014, 'phFFT420', 'Golz', 'Freq', 'Norm')
# (3016, 'phFFT422', 'Golz', 'Freq', 'Norm')
# (3017, 'phFFT423', 'Golz', 'Freq', 'Norm')
# (3018, 'phFFT424', 'Golz', 'Freq', 'Norm')
# (3019, 'phFFT425', 'Golz', 'Freq', 'Norm')
# (3020, 'phFFT426', 'Golz', 'Freq', 'Norm')
# (3021, 'phFFT427', 'Golz', 'Freq', 'Norm')
# (3022, 'phFFT428', 'Golz', 'Freq', 'Norm')
# (3023, 'phFFT429', 'Golz', 'Freq', 'Norm')
# (3024, 'phFFT430', 'Golz', 'Freq', 'Norm')
# (3025, 'phFFT431', 'Golz', 'Freq', 'Norm')
# (3027, 'phFFT433', 'Golz', 'Freq', 'Norm')
# (3028, 'phFFT434', 'Golz', 'Freq', 'Norm')
# (3030, 'phFFT436', 'Golz', 'Freq', 'Norm')
# (3031, 'phFFT437', 'Golz', 'Freq', 'Norm')
# (3032, 'phFFT438', 'Golz', 'Freq', 'Norm')
# (3033, 'phFFT439', 'Golz', 'Freq', 'Norm')
# (3034, 'phFFT440', 'Golz', 'Freq', 'Norm')
# (3035, 'phFFT441', 'Golz', 'Freq', 'Norm')
# (3036, 'phFFT442', 'Golz', 'Freq', 'Norm')
# (3037, 'phFFT443', 'Golz', 'Freq', 'Norm')
# (3038, 'phFFT444', 'Golz', 'Freq', 'Norm')
# (3039, 'phFFT445', 'Golz', 'Freq', 'Norm')
# (3040, 'phFFT446', 'Golz', 'Freq', 'Norm')
# (3041, 'phFFT447', 'Golz', 'Freq', 'Norm')
# (3042, 'phFFT448', 'Golz', 'Freq', 'Norm')
# (3043, 'phFFT449', 'Golz', 'Freq', 'Norm')
# (3044, 'phFFT450', 'Golz', 'Freq', 'Norm')
# (3045, 'phFFT451', 'Golz', 'Freq', 'Norm')
# (3046, 'phFFT452', 'Golz', 'Freq', 'Norm')
# (3047, 'phFFT453', 'Golz', 'Freq', 'Norm')
# (3048, 'phFFT454', 'Golz', 'Freq', 'Norm')
# (3049, 'phFFT455', 'Golz', 'Freq', 'Norm')
# (3050, 'phFFT456', 'Golz', 'Freq', 'Norm')
# (3051, 'phFFT457', 'Golz', 'Freq', 'Norm')
# (3052, 'phFFT458', 'Golz', 'Freq', 'Norm')
# (3054, 'phFFT460', 'Golz', 'Freq', 'Norm')
# (3056, 'phFFT462', 'Golz', 'Freq', 'Norm')
# (3057, 'phFFT463', 'Golz', 'Freq', 'Norm')
# (3058, 'phFFT464', 'Golz', 'Freq', 'Norm')
# (3060, 'phFFT466', 'Golz', 'Freq', 'Norm')
# (3061, 'phFFT467', 'Golz', 'Freq', 'Norm')
# (3062, 'phFFT468', 'Golz', 'Freq', 'Norm')
# (3065, 'phFFT471', 'Golz', 'Freq', 'Norm')
# (3066, 'phFFT472', 'Golz', 'Freq', 'Norm')
# (3067, 'phFFT473', 'Golz', 'Freq', 'Norm')
# (3068, 'phFFT474', 'Golz', 'Freq', 'Norm')
# (3069, 'phFFT475', 'Golz', 'Freq', 'Norm')
# (3070, 'phFFT476', 'Golz', 'Freq', 'Norm')
# (3071, 'phFFT477', 'Golz', 'Freq', 'Norm')
# (3072, 'phFFT478', 'Golz', 'Freq', 'Norm')
# (3073, 'phFFT479', 'Golz', 'Freq', 'Norm')
# (3074, 'phFFT480', 'Golz', 'Freq', 'Norm')
# (3075, 'phFFT481', 'Golz', 'Freq', 'Norm')
# (3076, 'phFFT482', 'Golz', 'Freq', 'Norm')
# (3077, 'phFFT483', 'Golz', 'Freq', 'Norm')
# (3078, 'phFFT484', 'Golz', 'Freq', 'Norm')
# (3079, 'phFFT485', 'Golz', 'Freq', 'Norm')
# (3080, 'phFFT486', 'Golz', 'Freq', 'Norm')
# (3081, 'phFFT487', 'Golz', 'Freq', 'Norm')
# (3082, 'phFFT488', 'Golz', 'Freq', 'Norm')
# (3083, 'phFFT489', 'Golz', 'Freq', 'Norm')
# (3084, 'phFFT490', 'Golz', 'Freq', 'Norm')
# (3085, 'phFFT491', 'Golz', 'Freq', 'Norm')
# (3086, 'phFFT492', 'Golz', 'Freq', 'Norm')
# (3087, 'phFFT493', 'Golz', 'Freq', 'Norm')
# (3088, 'phFFT494', 'Golz', 'Freq', 'Norm')
# (3089, 'phFFT495', 'Golz', 'Freq', 'Norm')
# (3090, 'phFFT496', 'Golz', 'Freq', 'Norm')
# (3091, 'phFFT497', 'Golz', 'Freq', 'Norm')
# (3092, 'phFFT498', 'Golz', 'Freq', 'Norm')
# (3093, 'phFFT499', 'Golz', 'Freq', 'Norm')
# (3094, 'phFFT500', 'Golz', 'Freq', 'Norm')
# (3095, 'phFFT501', 'Golz', 'Freq', 'Norm')
# (3096, 'phFFT502', 'Golz', 'Freq', 'Norm')
# (3097, 'phFFT503', 'Golz', 'Freq', 'Norm')
# (3099, 'phFFT505', 'Golz', 'Freq', 'Norm')
# (3100, 'phFFT506', 'Golz', 'Freq', 'Norm')
# (3101, 'phFFT507', 'Golz', 'Freq', 'Norm')
# (3102, 'phFFT508', 'Golz', 'Freq', 'Norm')
# (3103, 'phFFT509', 'Golz', 'Freq', 'Norm')
# (3104, 'phFFT510', 'Golz', 'Freq', 'Norm')
# (3105, 'phFFT511', 'Golz', 'Freq', 'Norm')
# (3106, 'phFFT512', 'Golz', 'Freq', 'Norm')
# (0, 'intsgnl', 'Phin', 'Time', 'Norm')
# (1, 'meanabs', 'Phin', 'Time', 'Norm')
# (3, 'ssi', 'Phin', 'Time', 'Norm')
# (4, 'var', 'Phin', 'Time', 'Norm')
# (5, 'rms', 'Phin', 'Time', 'Norm')
# (17, 'mnf', 'Phin', 'Freq', 'Norm')
# (21, 'reFFT000', 'Phin', 'Freq', 'Norm')
# (34, 'reFFT013', 'Phin', 'Freq', 'Norm')
# (37, 'reFFT016', 'Phin', 'Freq', 'Norm')
# (38, 'reFFT017', 'Phin', 'Freq', 'Norm')
# (39, 'reFFT018', 'Phin', 'Freq', 'Norm')
# (329, 'reFFT308', 'Phin', 'Freq', 'Norm')
# (330, 'reFFT309', 'Phin', 'Freq', 'Norm')
# (331, 'reFFT310', 'Phin', 'Freq', 'Norm')
# (332, 'reFFT311', 'Phin', 'Freq', 'Norm')
# (333, 'reFFT312', 'Phin', 'Freq', 'Norm')
# (334, 'reFFT313', 'Phin', 'Freq', 'Norm')
# (335, 'reFFT314', 'Phin', 'Freq', 'Norm')
# (337, 'reFFT316', 'Phin', 'Freq', 'Norm')
# (338, 'reFFT317', 'Phin', 'Freq', 'Norm')
# (339, 'reFFT318', 'Phin', 'Freq', 'Norm')
# (340, 'reFFT319', 'Phin', 'Freq', 'Norm')
# (342, 'reFFT321', 'Phin', 'Freq', 'Norm')
# (343, 'reFFT322', 'Phin', 'Freq', 'Norm')
# (344, 'reFFT323', 'Phin', 'Freq', 'Norm')
# (345, 'reFFT324', 'Phin', 'Freq', 'Norm')
# (346, 'reFFT325', 'Phin', 'Freq', 'Norm')
# (347, 'reFFT326', 'Phin', 'Freq', 'Norm')
# (348, 'reFFT327', 'Phin', 'Freq', 'Norm')
# (349, 'reFFT328', 'Phin', 'Freq', 'Norm')
# (351, 'reFFT330', 'Phin', 'Freq', 'Norm')
# (353, 'reFFT332', 'Phin', 'Freq', 'Norm')
# (355, 'reFFT334', 'Phin', 'Freq', 'Norm')
# (356, 'reFFT335', 'Phin', 'Freq', 'Norm')
# (357, 'reFFT336', 'Phin', 'Freq', 'Norm')
# (358, 'reFFT337', 'Phin', 'Freq', 'Norm')
# (360, 'reFFT339', 'Phin', 'Freq', 'Norm')
# (361, 'reFFT340', 'Phin', 'Freq', 'Norm')
# (362, 'reFFT341', 'Phin', 'Freq', 'Norm')
# (363, 'reFFT342', 'Phin', 'Freq', 'Norm')
# (364, 'reFFT343', 'Phin', 'Freq', 'Norm')
# (365, 'reFFT344', 'Phin', 'Freq', 'Norm')
# (367, 'reFFT346', 'Phin', 'Freq', 'Norm')
# (368, 'reFFT347', 'Phin', 'Freq', 'Norm')
# (369, 'reFFT348', 'Phin', 'Freq', 'Norm')
# (370, 'reFFT349', 'Phin', 'Freq', 'Norm')
# (371, 'reFFT350', 'Phin', 'Freq', 'Norm')
# (374, 'reFFT353', 'Phin', 'Freq', 'Norm')
# (375, 'reFFT354', 'Phin', 'Freq', 'Norm')
# (378, 'reFFT357', 'Phin', 'Freq', 'Norm')
# (379, 'reFFT358', 'Phin', 'Freq', 'Norm')
# (381, 'reFFT360', 'Phin', 'Freq', 'Norm')
# (382, 'reFFT361', 'Phin', 'Freq', 'Norm')
# (387, 'reFFT366', 'Phin', 'Freq', 'Norm')
# (388, 'reFFT367', 'Phin', 'Freq', 'Norm')
# (389, 'reFFT368', 'Phin', 'Freq', 'Norm')
# (391, 'reFFT370', 'Phin', 'Freq', 'Norm')
# (392, 'reFFT371', 'Phin', 'Freq', 'Norm')
# (400, 'reFFT379', 'Phin', 'Freq', 'Norm')
# (401, 'reFFT380', 'Phin', 'Freq', 'Norm')
# (405, 'reFFT384', 'Phin', 'Freq', 'Norm')
# (409, 'reFFT388', 'Phin', 'Freq', 'Norm')
# (549, 'imFFT015', 'Phin', 'Freq', 'Norm')
# (559, 'imFFT025', 'Phin', 'Freq', 'Norm')
# (560, 'imFFT026', 'Phin', 'Freq', 'Norm')
# (562, 'imFFT028', 'Phin', 'Freq', 'Norm')
# (564, 'imFFT030', 'Phin', 'Freq', 'Norm')
# (567, 'imFFT033', 'Phin', 'Freq', 'Norm')
# (568, 'imFFT034', 'Phin', 'Freq', 'Norm')
# (571, 'imFFT037', 'Phin', 'Freq', 'Norm')
# (845, 'imFFT311', 'Phin', 'Freq', 'Norm')
# (850, 'imFFT316', 'Phin', 'Freq', 'Norm')
# (852, 'imFFT318', 'Phin', 'Freq', 'Norm')
# (856, 'imFFT322', 'Phin', 'Freq', 'Norm')
# (858, 'imFFT324', 'Phin', 'Freq', 'Norm')
# (860, 'imFFT326', 'Phin', 'Freq', 'Norm')
# (861, 'imFFT327', 'Phin', 'Freq', 'Norm')
# (862, 'imFFT328', 'Phin', 'Freq', 'Norm')
# (863, 'imFFT329', 'Phin', 'Freq', 'Norm')
# (864, 'imFFT330', 'Phin', 'Freq', 'Norm')
# (865, 'imFFT331', 'Phin', 'Freq', 'Norm')
# (866, 'imFFT332', 'Phin', 'Freq', 'Norm')
# (867, 'imFFT333', 'Phin', 'Freq', 'Norm')
# (868, 'imFFT334', 'Phin', 'Freq', 'Norm')
# (869, 'imFFT335', 'Phin', 'Freq', 'Norm')
# (870, 'imFFT336', 'Phin', 'Freq', 'Norm')
# (871, 'imFFT337', 'Phin', 'Freq', 'Norm')
# (872, 'imFFT338', 'Phin', 'Freq', 'Norm')
# (873, 'imFFT339', 'Phin', 'Freq', 'Norm')
# (874, 'imFFT340', 'Phin', 'Freq', 'Norm')
# (875, 'imFFT341', 'Phin', 'Freq', 'Norm')
# (876, 'imFFT342', 'Phin', 'Freq', 'Norm')
# (877, 'imFFT343', 'Phin', 'Freq', 'Norm')
# (878, 'imFFT344', 'Phin', 'Freq', 'Norm')
# (879, 'imFFT345', 'Phin', 'Freq', 'Norm')
# (880, 'imFFT346', 'Phin', 'Freq', 'Norm')
# (881, 'imFFT347', 'Phin', 'Freq', 'Norm')
# (882, 'imFFT348', 'Phin', 'Freq', 'Norm')
# (883, 'imFFT349', 'Phin', 'Freq', 'Norm')
# (884, 'imFFT350', 'Phin', 'Freq', 'Norm')
# (885, 'imFFT351', 'Phin', 'Freq', 'Norm')
# (886, 'imFFT352', 'Phin', 'Freq', 'Norm')
# (887, 'imFFT353', 'Phin', 'Freq', 'Norm')
# (888, 'imFFT354', 'Phin', 'Freq', 'Norm')
# (889, 'imFFT355', 'Phin', 'Freq', 'Norm')
# (890, 'imFFT356', 'Phin', 'Freq', 'Norm')
# (891, 'imFFT357', 'Phin', 'Freq', 'Norm')
# (893, 'imFFT359', 'Phin', 'Freq', 'Norm')
# (894, 'imFFT360', 'Phin', 'Freq', 'Norm')
# (895, 'imFFT361', 'Phin', 'Freq', 'Norm')
# (896, 'imFFT362', 'Phin', 'Freq', 'Norm')
# (897, 'imFFT363', 'Phin', 'Freq', 'Norm')
# (898, 'imFFT364', 'Phin', 'Freq', 'Norm')
# (899, 'imFFT365', 'Phin', 'Freq', 'Norm')
# (900, 'imFFT366', 'Phin', 'Freq', 'Norm')
# (901, 'imFFT367', 'Phin', 'Freq', 'Norm')
# (902, 'imFFT368', 'Phin', 'Freq', 'Norm')
# (903, 'imFFT369', 'Phin', 'Freq', 'Norm')
# (904, 'imFFT370', 'Phin', 'Freq', 'Norm')
# (905, 'imFFT371', 'Phin', 'Freq', 'Norm')
# (906, 'imFFT372', 'Phin', 'Freq', 'Norm')
# (907, 'imFFT373', 'Phin', 'Freq', 'Norm')
# (908, 'imFFT374', 'Phin', 'Freq', 'Norm')
# (909, 'imFFT375', 'Phin', 'Freq', 'Norm')
# (910, 'imFFT376', 'Phin', 'Freq', 'Norm')
# (911, 'imFFT377', 'Phin', 'Freq', 'Norm')
# (912, 'imFFT378', 'Phin', 'Freq', 'Norm')
# (913, 'imFFT379', 'Phin', 'Freq', 'Norm')
# (914, 'imFFT380', 'Phin', 'Freq', 'Norm')
# (915, 'imFFT381', 'Phin', 'Freq', 'Norm')
# (916, 'imFFT382', 'Phin', 'Freq', 'Norm')
# (917, 'imFFT383', 'Phin', 'Freq', 'Norm')
# (918, 'imFFT384', 'Phin', 'Freq', 'Norm')
# (919, 'imFFT385', 'Phin', 'Freq', 'Norm')
# (921, 'imFFT387', 'Phin', 'Freq', 'Norm')
# (922, 'imFFT388', 'Phin', 'Freq', 'Norm')
# (923, 'imFFT389', 'Phin', 'Freq', 'Norm')
# (924, 'imFFT390', 'Phin', 'Freq', 'Norm')
# (925, 'imFFT391', 'Phin', 'Freq', 'Norm')
# (926, 'imFFT392', 'Phin', 'Freq', 'Norm')
# (927, 'imFFT393', 'Phin', 'Freq', 'Norm')
# (928, 'imFFT394', 'Phin', 'Freq', 'Norm')
# (929, 'imFFT395', 'Phin', 'Freq', 'Norm')
# (930, 'imFFT396', 'Phin', 'Freq', 'Norm')
# (931, 'imFFT397', 'Phin', 'Freq', 'Norm')
# (932, 'imFFT398', 'Phin', 'Freq', 'Norm')
# (933, 'imFFT399', 'Phin', 'Freq', 'Norm')
# (934, 'imFFT400', 'Phin', 'Freq', 'Norm')
# (935, 'imFFT401', 'Phin', 'Freq', 'Norm')
# (936, 'imFFT402', 'Phin', 'Freq', 'Norm')
# (937, 'imFFT403', 'Phin', 'Freq', 'Norm')
# (939, 'imFFT405', 'Phin', 'Freq', 'Norm')
# (940, 'imFFT406', 'Phin', 'Freq', 'Norm')
# (941, 'imFFT407', 'Phin', 'Freq', 'Norm')
# (942, 'imFFT408', 'Phin', 'Freq', 'Norm')
# (943, 'imFFT409', 'Phin', 'Freq', 'Norm')
# (944, 'imFFT410', 'Phin', 'Freq', 'Norm')
# (945, 'imFFT411', 'Phin', 'Freq', 'Norm')
# (946, 'imFFT412', 'Phin', 'Freq', 'Norm')
# (947, 'imFFT413', 'Phin', 'Freq', 'Norm')
# (949, 'imFFT415', 'Phin', 'Freq', 'Norm')
# (950, 'imFFT416', 'Phin', 'Freq', 'Norm')
# (951, 'imFFT417', 'Phin', 'Freq', 'Norm')
# (952, 'imFFT418', 'Phin', 'Freq', 'Norm')
# (957, 'imFFT423', 'Phin', 'Freq', 'Norm')
# (958, 'imFFT424', 'Phin', 'Freq', 'Norm')
# (959, 'imFFT425', 'Phin', 'Freq', 'Norm')
# (960, 'imFFT426', 'Phin', 'Freq', 'Norm')
# ...
# (2120, 'amFFT039', 'Golz', 'Freq', 'Norm')
# (2121, 'amFFT040', 'Golz', 'Freq', 'Norm')
# (2122, 'amFFT041', 'Golz', 'Freq', 'Norm')
# (2123, 'amFFT042', 'Golz', 'Freq', 'Norm')
# (2124, 'amFFT043', 'Golz', 'Freq', 'Norm')
# (2125, 'amFFT044', 'Golz', 'Freq', 'Norm')
# (2126, 'amFFT045', 'Golz', 'Freq', 'Norm')
# (2127, 'amFFT046', 'Golz', 'Freq', 'Norm')
# (2128, 'amFFT047', 'Golz', 'Freq', 'Norm')
# (2129, 'amFFT048', 'Golz', 'Freq', 'Norm')
# (2130, 'amFFT049', 'Golz', 'Freq', 'Norm')
# (2131, 'amFFT050', 'Golz', 'Freq', 'Norm')
# (2132, 'amFFT051', 'Golz', 'Freq', 'Norm')
# (2133, 'amFFT052', 'Golz', 'Freq', 'Norm')
# (2134, 'amFFT053', 'Golz', 'Freq', 'Norm')
# (2135, 'amFFT054', 'Golz', 'Freq', 'Norm')
# (2136, 'amFFT055', 'Golz', 'Freq', 'Norm')
# (2137, 'amFFT056', 'Golz', 'Freq', 'Norm')
# (2138, 'amFFT057', 'Golz', 'Freq', 'Norm')
# (2594, 'phFFT000', 'Golz', 'Freq', 'Norm')
# (2622, 'phFFT028', 'Golz', 'Freq', 'Norm')
# (2630, 'phFFT036', 'Golz', 'Freq', 'Norm')
# (2633, 'phFFT039', 'Golz', 'Freq', 'Norm')
# (2634, 'phFFT040', 'Golz', 'Freq', 'Norm')
# (2635, 'phFFT041', 'Golz', 'Freq', 'Norm')
# (2636, 'phFFT042', 'Golz', 'Freq', 'Norm')
# (2637, 'phFFT043', 'Golz', 'Freq', 'Norm')
# (2638, 'phFFT044', 'Golz', 'Freq', 'Norm')
# (2639, 'phFFT045', 'Golz', 'Freq', 'Norm')
# (2640, 'phFFT046', 'Golz', 'Freq', 'Norm')
# (2641, 'phFFT047', 'Golz', 'Freq', 'Norm')
# (2642, 'phFFT048', 'Golz', 'Freq', 'Norm')
# (2643, 'phFFT049', 'Golz', 'Freq', 'Norm')
# (2644, 'phFFT050', 'Golz', 'Freq', 'Norm')
# (2645, 'phFFT051', 'Golz', 'Freq', 'Norm')
# (2646, 'phFFT052', 'Golz', 'Freq', 'Norm')
# (2647, 'phFFT053', 'Golz', 'Freq', 'Norm')
# (2648, 'phFFT054', 'Golz', 'Freq', 'Norm')
# (2649, 'phFFT055', 'Golz', 'Freq', 'Norm')
# (2650, 'phFFT056', 'Golz', 'Freq', 'Norm')
# (2651, 'phFFT057', 'Golz', 'Freq', 'Norm')
# (2, 'meanabsslp', 'Phin', 'Time', 'Norm')
# (6, 'rng', 'Phin', 'Time', 'Norm')
# (19, 'mmnf', 'Phin', 'Freq', 'Norm')
# (20, 'mmdf', 'Phin', 'Freq', 'Norm')
# (22, 'reFFT001', 'Phin', 'Freq', 'Norm')
# (23, 'reFFT002', 'Phin', 'Freq', 'Norm')
# (24, 'reFFT003', 'Phin', 'Freq', 'Norm')
# (25, 'reFFT004', 'Phin', 'Freq', 'Norm')
# (26, 'reFFT005', 'Phin', 'Freq', 'Norm')
# (27, 'reFFT006', 'Phin', 'Freq', 'Norm')
# (28, 'reFFT007', 'Phin', 'Freq', 'Norm')
# (29, 'reFFT008', 'Phin', 'Freq', 'Norm')
# (30, 'reFFT009', 'Phin', 'Freq', 'Norm')
# (31, 'reFFT010', 'Phin', 'Freq', 'Norm')
# (32, 'reFFT011', 'Phin', 'Freq', 'Norm')
# (33, 'reFFT012', 'Phin', 'Freq', 'Norm')
# (35, 'reFFT014', 'Phin', 'Freq', 'Norm')
# (350, 'reFFT329', 'Phin', 'Freq', 'Norm')
# (352, 'reFFT331', 'Phin', 'Freq', 'Norm')
# (354, 'reFFT333', 'Phin', 'Freq', 'Norm')
# (359, 'reFFT338', 'Phin', 'Freq', 'Norm')
# (366, 'reFFT345', 'Phin', 'Freq', 'Norm')
# (372, 'reFFT351', 'Phin', 'Freq', 'Norm')
# (373, 'reFFT352', 'Phin', 'Freq', 'Norm')
# (376, 'reFFT355', 'Phin', 'Freq', 'Norm')
# (377, 'reFFT356', 'Phin', 'Freq', 'Norm')
# (380, 'reFFT359', 'Phin', 'Freq', 'Norm')
# (383, 'reFFT362', 'Phin', 'Freq', 'Norm')
# (384, 'reFFT363', 'Phin', 'Freq', 'Norm')
# (385, 'reFFT364', 'Phin', 'Freq', 'Norm')
# (386, 'reFFT365', 'Phin', 'Freq', 'Norm')
# (390, 'reFFT369', 'Phin', 'Freq', 'Norm')
# (393, 'reFFT372', 'Phin', 'Freq', 'Norm')
# (394, 'reFFT373', 'Phin', 'Freq', 'Norm')
# (395, 'reFFT374', 'Phin', 'Freq', 'Norm')
# (396, 'reFFT375', 'Phin', 'Freq', 'Norm')
# (397, 'reFFT376', 'Phin', 'Freq', 'Norm')
# (398, 'reFFT377', 'Phin', 'Freq', 'Norm')
# (399, 'reFFT378', 'Phin', 'Freq', 'Norm')
# (402, 'reFFT381', 'Phin', 'Freq', 'Norm')
# (403, 'reFFT382', 'Phin', 'Freq', 'Norm')
# (404, 'reFFT383', 'Phin', 'Freq', 'Norm')
# (406, 'reFFT385', 'Phin', 'Freq', 'Norm')
# (407, 'reFFT386', 'Phin', 'Freq', 'Norm')
# (408, 'reFFT387', 'Phin', 'Freq', 'Norm')
# (410, 'reFFT389', 'Phin', 'Freq', 'Norm')
# (411, 'reFFT390', 'Phin', 'Freq', 'Norm')
# (412, 'reFFT391', 'Phin', 'Freq', 'Norm')
# (413, 'reFFT392', 'Phin', 'Freq', 'Norm')
# (414, 'reFFT393', 'Phin', 'Freq', 'Norm')
# (415, 'reFFT394', 'Phin', 'Freq', 'Norm')
# (416, 'reFFT395', 'Phin', 'Freq', 'Norm')
# (417, 'reFFT396', 'Phin', 'Freq', 'Norm')
# (418, 'reFFT397', 'Phin', 'Freq', 'Norm')
# (419, 'reFFT398', 'Phin', 'Freq', 'Norm')
# (420, 'reFFT399', 'Phin', 'Freq', 'Norm')
# (421, 'reFFT400', 'Phin', 'Freq', 'Norm')
# (422, 'reFFT401', 'Phin', 'Freq', 'Norm')
# (423, 'reFFT402', 'Phin', 'Freq', 'Norm')
# (424, 'reFFT403', 'Phin', 'Freq', 'Norm')
# (425, 'reFFT404', 'Phin', 'Freq', 'Norm')
# (426, 'reFFT405', 'Phin', 'Freq', 'Norm')
# (427, 'reFFT406', 'Phin', 'Freq', 'Norm')
# (428, 'reFFT407', 'Phin', 'Freq', 'Norm')
# (429, 'reFFT408', 'Phin', 'Freq', 'Norm')
# (430, 'reFFT409', 'Phin', 'Freq', 'Norm')
# (431, 'reFFT410', 'Phin', 'Freq', 'Norm')
# (432, 'reFFT411', 'Phin', 'Freq', 'Norm')
# (433, 'reFFT412', 'Phin', 'Freq', 'Norm')
# (434, 'reFFT413', 'Phin', 'Freq', 'Norm')
# (435, 'reFFT414', 'Phin', 'Freq', 'Norm')
# (436, 'reFFT415', 'Phin', 'Freq', 'Norm')
# (437, 'reFFT416', 'Phin', 'Freq', 'Norm')
# (438, 'reFFT417', 'Phin', 'Freq', 'Norm')
# (439, 'reFFT418', 'Phin', 'Freq', 'Norm')
# (440, 'reFFT419', 'Phin', 'Freq', 'Norm')
# (441, 'reFFT420', 'Phin', 'Freq', 'Norm')
# (442, 'reFFT421', 'Phin', 'Freq', 'Norm')
# (443, 'reFFT422', 'Phin', 'Freq', 'Norm')
# (444, 'reFFT423', 'Phin', 'Freq', 'Norm')
# (445, 'reFFT424', 'Phin', 'Freq', 'Norm')
# (446, 'reFFT425', 'Phin', 'Freq', 'Norm')
# (447, 'reFFT426', 'Phin', 'Freq', 'Norm')
# (448, 'reFFT427', 'Phin', 'Freq', 'Norm')
# (449, 'reFFT428', 'Phin', 'Freq', 'Norm')
# (450, 'reFFT429', 'Phin', 'Freq', 'Norm')
# (451, 'reFFT430', 'Phin', 'Freq', 'Norm')
# (452, 'reFFT431', 'Phin', 'Freq', 'Norm')
# (453, 'reFFT432', 'Phin', 'Freq', 'Norm')
# (454, 'reFFT433', 'Phin', 'Freq', 'Norm')
# (455, 'reFFT434', 'Phin', 'Freq', 'Norm')
# (456, 'reFFT435', 'Phin', 'Freq', 'Norm')
# (457, 'reFFT436', 'Phin', 'Freq', 'Norm')
# (458, 'reFFT437', 'Phin', 'Freq', 'Norm')
# (459, 'reFFT438', 'Phin', 'Freq', 'Norm')
# (460, 'reFFT439', 'Phin', 'Freq', 'Norm')
# (461, 'reFFT440', 'Phin', 'Freq', 'Norm')
# (462, 'reFFT441', 'Phin', 'Freq', 'Norm')
# (463, 'reFFT442', 'Phin', 'Freq', 'Norm')
# (464, 'reFFT443', 'Phin', 'Freq', 'Norm')
# (465, 'reFFT444', 'Phin', 'Freq', 'Norm')
# (466, 'reFFT445', 'Phin', 'Freq', 'Norm')
# (467, 'reFFT446', 'Phin', 'Freq', 'Norm')
# (468, 'reFFT447', 'Phin', 'Freq', 'Norm')
# (469, 'reFFT448', 'Phin', 'Freq', 'Norm')
# (470, 'reFFT449', 'Phin', 'Freq', 'Norm')
# (471, 'reFFT450', 'Phin', 'Freq', 'Norm')
# (472, 'reFFT451', 'Phin', 'Freq', 'Norm')
# (473, 'reFFT452', 'Phin', 'Freq', 'Norm')
# (474, 'reFFT453', 'Phin', 'Freq', 'Norm')
# (475, 'reFFT454', 'Phin', 'Freq', 'Norm')
# (476, 'reFFT455', 'Phin', 'Freq', 'Norm')
# (477, 'reFFT456', 'Phin', 'Freq', 'Norm')
# (478, 'reFFT457', 'Phin', 'Freq', 'Norm')
# (479, 'reFFT458', 'Phin', 'Freq', 'Norm')
# (480, 'reFFT459', 'Phin', 'Freq', 'Norm')
# (481, 'reFFT460', 'Phin', 'Freq', 'Norm')
# (482, 'reFFT461', 'Phin', 'Freq', 'Norm')
# (483, 'reFFT462', 'Phin', 'Freq', 'Norm')
# (484, 'reFFT463', 'Phin', 'Freq', 'Norm')
# (485, 'reFFT464', 'Phin', 'Freq', 'Norm')
# (486, 'reFFT465', 'Phin', 'Freq', 'Norm')
# (487, 'reFFT466', 'Phin', 'Freq', 'Norm')
# (488, 'reFFT467', 'Phin', 'Freq', 'Norm')
# (489, 'reFFT468', 'Phin', 'Freq', 'Norm')
# (490, 'reFFT469', 'Phin', 'Freq', 'Norm')
# (491, 'reFFT470', 'Phin', 'Freq', 'Norm')
# (492, 'reFFT471', 'Phin', 'Freq', 'Norm')
# (493, 'reFFT472', 'Phin', 'Freq', 'Norm')
# (494, 'reFFT473', 'Phin', 'Freq', 'Norm')
# (495, 'reFFT474', 'Phin', 'Freq', 'Norm')
# (496, 'reFFT475', 'Phin', 'Freq', 'Norm')
# (497, 'reFFT476', 'Phin', 'Freq', 'Norm')
# (498, 'reFFT477', 'Phin', 'Freq', 'Norm')
# (499, 'reFFT478', 'Phin', 'Freq', 'Norm')
# (500, 'reFFT479', 'Phin', 'Freq', 'Norm')
# (501, 'reFFT480', 'Phin', 'Freq', 'Norm')
# (502, 'reFFT481', 'Phin', 'Freq', 'Norm')
# (503, 'reFFT482', 'Phin', 'Freq', 'Norm')
# (504, 'reFFT483', 'Phin', 'Freq', 'Norm')
# (505, 'reFFT484', 'Phin', 'Freq', 'Norm')
# (506, 'reFFT485', 'Phin', 'Freq', 'Norm')
# (507, 'reFFT486', 'Phin', 'Freq', 'Norm')
# (508, 'reFFT487', 'Phin', 'Freq', 'Norm')
# (509, 'reFFT488', 'Phin', 'Freq', 'Norm')
# (510, 'reFFT489', 'Phin', 'Freq', 'Norm')
# (511, 'reFFT490', 'Phin', 'Freq', 'Norm')
# (512, 'reFFT491', 'Phin', 'Freq', 'Norm')
# (513, 'reFFT492', 'Phin', 'Freq', 'Norm')
# (514, 'reFFT493', 'Phin', 'Freq', 'Norm')
# (515, 'reFFT494', 'Phin', 'Freq', 'Norm')
# (516, 'reFFT495', 'Phin', 'Freq', 'Norm')
# (517, 'reFFT496', 'Phin', 'Freq', 'Norm')
# (518, 'reFFT497', 'Phin', 'Freq', 'Norm')
# (519, 'reFFT498', 'Phin', 'Freq', 'Norm')
# (520, 'reFFT499', 'Phin', 'Freq', 'Norm')
# (521, 'reFFT500', 'Phin', 'Freq', 'Norm')
# (522, 'reFFT501', 'Phin', 'Freq', 'Norm')
# (523, 'reFFT502', 'Phin', 'Freq', 'Norm')
# (524, 'reFFT503', 'Phin', 'Freq', 'Norm')
# (525, 'reFFT504', 'Phin', 'Freq', 'Norm')
# (526, 'reFFT505', 'Phin', 'Freq', 'Norm')
# (527, 'reFFT506', 'Phin', 'Freq', 'Norm')
# (528, 'reFFT507', 'Phin', 'Freq', 'Norm')
# (529, 'reFFT508', 'Phin', 'Freq', 'Norm')
# (530, 'reFFT509', 'Phin', 'Freq', 'Norm')
# (531, 'reFFT510', 'Phin', 'Freq', 'Norm')
# (532, 'reFFT511', 'Phin', 'Freq', 'Norm')
# (533, 'reFFT512', 'Phin', 'Freq', 'Norm')
# (535, 'imFFT001', 'Phin', 'Freq', 'Norm')
# (536, 'imFFT002', 'Phin', 'Freq', 'Norm')
# (537, 'imFFT003', 'Phin', 'Freq', 'Norm')
# (538, 'imFFT004', 'Phin', 'Freq', 'Norm')
# (539, 'imFFT005', 'Phin', 'Freq', 'Norm')
# (540, 'imFFT006', 'Phin', 'Freq', 'Norm')
# (541, 'imFFT007', 'Phin', 'Freq', 'Norm')
# (542, 'imFFT008', 'Phin', 'Freq', 'Norm')
# (543, 'imFFT009', 'Phin', 'Freq', 'Norm')
# (544, 'imFFT010', 'Phin', 'Freq', 'Norm')
# (545, 'imFFT011', 'Phin', 'Freq', 'Norm')
# (546, 'imFFT012', 'Phin', 'Freq', 'Norm')
# (547, 'imFFT013', 'Phin', 'Freq', 'Norm')
# (548, 'imFFT014', 'Phin', 'Freq', 'Norm')
# (550, 'imFFT016', 'Phin', 'Freq', 'Norm')
# (551, 'imFFT017', 'Phin', 'Freq', 'Norm')
# (552, 'imFFT018', 'Phin', 'Freq', 'Norm')
# (553, 'imFFT019', 'Phin', 'Freq', 'Norm')
# (554, 'imFFT020', 'Phin', 'Freq', 'Norm')
# (555, 'imFFT021', 'Phin', 'Freq', 'Norm')
# (556, 'imFFT022', 'Phin', 'Freq', 'Norm')
# (557, 'imFFT023', 'Phin', 'Freq', 'Norm')
# (563, 'imFFT029', 'Phin', 'Freq', 'Norm')
# (569, 'imFFT035', 'Phin', 'Freq', 'Norm')
# (892, 'imFFT358', 'Phin', 'Freq', 'Norm')
# (920, 'imFFT386', 'Phin', 'Freq', 'Norm')
# (938, 'imFFT404', 'Phin', 'Freq', 'Norm')
# (948, 'imFFT414', 'Phin', 'Freq', 'Norm')
# (953, 'imFFT419', 'Phin', 'Freq', 'Norm')
# (954, 'imFFT420', 'Phin', 'Freq', 'Norm')
# (955, 'imFFT421', 'Phin', 'Freq', 'Norm')
# (956, 'imFFT422', 'Phin', 'Freq', 'Norm')
# (971, 'imFFT437', 'Phin', 'Freq', 'Norm')
# (973, 'imFFT439', 'Phin', 'Freq', 'Norm')
# (976, 'imFFT442', 'Phin', 'Freq', 'Norm')
# (978, 'imFFT444', 'Phin', 'Freq', 'Norm')
# (979, 'imFFT445', 'Phin', 'Freq', 'Norm')
# (985, 'imFFT451', 'Phin', 'Freq', 'Norm')
# (987, 'imFFT453', 'Phin', 'Freq', 'Norm')
# (997, 'imFFT463', 'Phin', 'Freq', 'Norm')
# (999, 'imFFT465', 'Phin', 'Freq', 'Norm')
# (1003, 'imFFT469', 'Phin', 'Freq', 'Norm')
# (1007, 'imFFT473', 'Phin', 'Freq', 'Norm')
# (1019, 'imFFT485', 'Phin', 'Freq', 'Norm')
# (1023, 'imFFT489', 'Phin', 'Freq', 'Norm')
# (1025, 'imFFT491', 'Phin', 'Freq', 'Norm')
# (1048, 'stdr', 'Golz', 'Time', 'Norm')
# (1049, 'mx', 'Golz', 'Time', 'Norm')
# (1051, 'rngy', 'Golz', 'Time', 'Norm')
# (1056, 'ssk', 'Golz', 'Time', 'Norm')
# (1058, 'acrol0001', 'Golz', 'Time', 'Norm')
# (1060, 'acrol0003', 'Golz', 'Time', 'Norm')
# (1063, 'acrol0006', 'Golz', 'Time', 'Norm')
# (1065, 'acrol0008', 'Golz', 'Time', 'Norm')
# (1068, 'acrol0011', 'Golz', 'Time', 'Norm')
# (1070, 'acrol0013', 'Golz', 'Time', 'Norm')
# (1071, 'acrol0014', 'Golz', 'Time', 'Norm')
# (1072, 'acrol0015', 'Golz', 'Time', 'Norm')
# (1073, 'acrol0016', 'Golz', 'Time', 'Norm')
# (1076, 'acrol0019', 'Golz', 'Time', 'Norm')
# (1077, 'acrol0020', 'Golz', 'Time', 'Norm')
# (1078, 'acrol0021', 'Golz', 'Time', 'Norm')
# (1079, 'acrol0022', 'Golz', 'Time', 'Norm')
# (1080, 'acrol0023', 'Golz', 'Time', 'Norm')
# (1081, 'acrol0024', 'Golz', 'Time', 'Norm')
# (1082, 'acrol0025', 'Golz', 'Time', 'Norm')
# (1083, 'acrol0026', 'Golz', 'Time', 'Norm')
# (1084, 'acrol0027', 'Golz', 'Time', 'Norm')
# (1085, 'acrol0028', 'Golz', 'Time', 'Norm')
# (1086, 'acrol0029', 'Golz', 'Time', 'Norm')
# (1087, 'acrol0030', 'Golz', 'Time', 'Norm')
# (1088, 'acrol0031', 'Golz', 'Time', 'Norm')
# (1090, 'acrol0033', 'Golz', 'Time', 'Norm')
# (1093, 'acrol0036', 'Golz', 'Time', 'Norm')
# (1096, 'acrol0039', 'Golz', 'Time', 'Norm')
# (1097, 'acrol0040', 'Golz', 'Time', 'Norm')
# (1098, 'acrol0041', 'Golz', 'Time', 'Norm')
# (1099, 'acrol0042', 'Golz', 'Time', 'Norm')
# (1100, 'acrol0043', 'Golz', 'Time', 'Norm')
# (1101, 'acrol0044', 'Golz', 'Time', 'Norm')
# (1103, 'acrol0046', 'Golz', 'Time', 'Norm')
# (1104, 'acrol0047', 'Golz', 'Time', 'Norm')
# (1105, 'acrol0048', 'Golz', 'Time', 'Norm')
# (1108, 'acrol0051', 'Golz', 'Time', 'Norm')
# (1111, 'acrol0054', 'Golz', 'Time', 'Norm')
# (1139, 'acrol0082', 'Golz', 'Time', 'Norm')
# (1143, 'acrol0086', 'Golz', 'Time', 'Norm')
# (1261, 'acrol0204', 'Golz', 'Time', 'Norm')
# (1262, 'acrol0205', 'Golz', 'Time', 'Norm')
# (1274, 'acrol0217', 'Golz', 'Time', 'Norm')
# (1275, 'acrol0218', 'Golz', 'Time', 'Norm')
# (1377, 'acrol0320', 'Golz', 'Time', 'Norm')
# (1432, 'acrol0375', 'Golz', 'Time', 'Norm')
# (1557, 'acrol0500', 'Golz', 'Time', 'Norm')
# (1794, 'acrol0737', 'Golz', 'Time', 'Norm')
# (2082, 'amFFT001', 'Golz', 'Freq', 'Norm')
# (2083, 'amFFT002', 'Golz', 'Freq', 'Norm')
# (2084, 'amFFT003', 'Golz', 'Freq', 'Norm')
# (2085, 'amFFT004', 'Golz', 'Freq', 'Norm')
# (2086, 'amFFT005', 'Golz', 'Freq', 'Norm')
# (2087, 'amFFT006', 'Golz', 'Freq', 'Norm')
# (2088, 'amFFT007', 'Golz', 'Freq', 'Norm')
# (2089, 'amFFT008', 'Golz', 'Freq', 'Norm')
# (2090, 'amFFT009', 'Golz', 'Freq', 'Norm')
# (2091, 'amFFT010', 'Golz', 'Freq', 'Norm')
# (2092, 'amFFT011', 'Golz', 'Freq', 'Norm')
# (2093, 'amFFT012', 'Golz', 'Freq', 'Norm')
# (2094, 'amFFT013', 'Golz', 'Freq', 'Norm')
# (2095, 'amFFT014', 'Golz', 'Freq', 'Norm')
# (2096, 'amFFT015', 'Golz', 'Freq', 'Norm')
# (2097, 'amFFT016', 'Golz', 'Freq', 'Norm')
# (2098, 'amFFT017', 'Golz', 'Freq', 'Norm')
# (2099, 'amFFT018', 'Golz', 'Freq', 'Norm')
# (2100, 'amFFT019', 'Golz', 'Freq', 'Norm')
# (2101, 'amFFT020', 'Golz', 'Freq', 'Norm')
# (2102, 'amFFT021', 'Golz', 'Freq', 'Norm')
# (2103, 'amFFT022', 'Golz', 'Freq', 'Norm')
# (2104, 'amFFT023', 'Golz', 'Freq', 'Norm')
# (2105, 'amFFT024', 'Golz', 'Freq', 'Norm')
# (2106, 'amFFT025', 'Golz', 'Freq', 'Norm')
# (2107, 'amFFT026', 'Golz', 'Freq', 'Norm')
# (2108, 'amFFT027', 'Golz', 'Freq', 'Norm')
# (2110, 'amFFT029', 'Golz', 'Freq', 'Norm')
# (2111, 'amFFT030', 'Golz', 'Freq', 'Norm')
# (2112, 'amFFT031', 'Golz', 'Freq', 'Norm')
# (2113, 'amFFT032', 'Golz', 'Freq', 'Norm')
# (2114, 'amFFT033', 'Golz', 'Freq', 'Norm')
# (2115, 'amFFT034', 'Golz', 'Freq', 'Norm')
# (2116, 'amFFT035', 'Golz', 'Freq', 'Norm')
# (2118, 'amFFT037', 'Golz', 'Freq', 'Norm')
# (2119, 'amFFT038', 'Golz', 'Freq', 'Norm')
# (2595, 'phFFT001', 'Golz', 'Freq', 'Norm')
# (2596, 'phFFT002', 'Golz', 'Freq', 'Norm')
# (2597, 'phFFT003', 'Golz', 'Freq', 'Norm')
# (2598, 'phFFT004', 'Golz', 'Freq', 'Norm')
# (2599, 'phFFT005', 'Golz', 'Freq', 'Norm')
# (2600, 'phFFT006', 'Golz', 'Freq', 'Norm')
# (2601, 'phFFT007', 'Golz', 'Freq', 'Norm')
# (2602, 'phFFT008', 'Golz', 'Freq', 'Norm')
# (2603, 'phFFT009', 'Golz', 'Freq', 'Norm')
# (2604, 'phFFT010', 'Golz', 'Freq', 'Norm')
# (2605, 'phFFT011', 'Golz', 'Freq', 'Norm')
# (2606, 'phFFT012', 'Golz', 'Freq', 'Norm')
# (2607, 'phFFT013', 'Golz', 'Freq', 'Norm')
# (2608, 'phFFT014', 'Golz', 'Freq', 'Norm')
# (2609, 'phFFT015', 'Golz', 'Freq', 'Norm')
# (2610, 'phFFT016', 'Golz', 'Freq', 'Norm')
# (2611, 'phFFT017', 'Golz', 'Freq', 'Norm')
# (2612, 'phFFT018', 'Golz', 'Freq', 'Norm')
# (2613, 'phFFT019', 'Golz', 'Freq', 'Norm')
# (2614, 'phFFT020', 'Golz', 'Freq', 'Norm')
# (2615, 'phFFT021', 'Golz', 'Freq', 'Norm')
# (2616, 'phFFT022', 'Golz', 'Freq', 'Norm')
# (2617, 'phFFT023', 'Golz', 'Freq', 'Norm')
# (2618, 'phFFT024', 'Golz', 'Freq', 'Norm')
# (2619, 'phFFT025', 'Golz', 'Freq', 'Norm')
# (2620, 'phFFT026', 'Golz', 'Freq', 'Norm')
# (2621, 'phFFT027', 'Golz', 'Freq', 'Norm')
# (2623, 'phFFT029', 'Golz', 'Freq', 'Norm')
# (2624, 'phFFT030', 'Golz', 'Freq', 'Norm')
# (2625, 'phFFT031', 'Golz', 'Freq', 'Norm')
# (2626, 'phFFT032', 'Golz', 'Freq', 'Norm')
# (2627, 'phFFT033', 'Golz', 'Freq', 'Norm')
# (2628, 'phFFT034', 'Golz', 'Freq', 'Norm')
# (2629, 'phFFT035', 'Golz', 'Freq', 'Norm')
# (2631, 'phFFT037', 'Golz', 'Freq', 'Norm')
# (2632, 'phFFT038', 'Golz', 'Freq', 'Norm')

# %%
feat_self_file = 'feat_sel_1_2.npz'
np.savez(feat_self_file,ids = nio, feat_mask = feat_mask)

# %%
# %%time
# validate between the different objects using the dataset from both fingers

# Version 2: keep alternatively one for testing and train on the rest

# ===================================== Hard-code this shit

data_X = deepcopy(X[2][0]) #[:-1]
data_Y = deepcopy(Y[2]) #[:-1]
print(data_X.shape)
surfaces = np.split(data_X,3)
surf_labels = np.split(data_Y,3) 
# feat_mask = []
temp1 = surfaces[0] 
train_x = np.concatenate((surfaces[2], surfaces[0]), axis = 0) ; test_x = surfaces[1]
train_y = np.concatenate((surf_labels[2], surf_labels[0]), axis = 0) ; test_y = surf_labels[1]
print(train_x.shape)
scaler = StandardScaler() ; featsel = SelectKBest(k=1000,score_func= mutual_info_classif)
decomp = PCA(n_components=20)
pipe_list = [make_pipe_clf(scaler,featsel, decomp, classifiers[i]) for i in range(len(classifiers))]

for pipe_ind, pipe in enumerate(pipe_list):
    pipe.fit(train_x, train_y)
    print("...done fitting")
    y_pred = pipe.predict(test_x)
    y_true = test_y
    cm = confusion_matrix(y_pred=y_pred, y_true=y_true)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print ("=============================================================")
    print("Testing with classifier %0.4s" %pipe.named_steps['classifier'])
    print("Prediction accuracy %f" %pipe.score(test_x,y_true))
    print(cm)
    print(classification_report(y_pred=y_pred, y_true = y_true))        
    print ("=============================================================")
# Out:
# (8898, 3107)
# (5932, 3107)
# ...done fitting
# =============================================================
# Testing with classifier KNei
# Prediction accuracy 0.876601
# [[ 0.88917693  0.11082307]
#  [ 0.13703443  0.86296557]]
#              precision    recall  f1-score   support
#
#         0.0       0.88      0.89      0.88      1543
#         1.0       0.88      0.86      0.87      1423
#
# avg / total       0.88      0.88      0.88      2966
#
# =============================================================
# ...done fitting
# =============================================================
# Testing with classifier SVC(
# Prediction accuracy 0.903574
# [[ 0.94426442  0.05573558]
#  [ 0.14054814  0.85945186]]
#              precision    recall  f1-score   support
#
#         0.0       0.88      0.94      0.91      1543
#         1.0       0.93      0.86      0.90      1423
#
# avg / total       0.91      0.90      0.90      2966
#
# =============================================================
# ...done fitting
# =============================================================
# Testing with classifier MLPC
# Prediction accuracy 0.915374
# [[ 0.94491251  0.05508749]
#  [ 0.11665495  0.88334505]]
#              precision    recall  f1-score   support
#
#         0.0       0.90      0.94      0.92      1543
#         1.0       0.94      0.88      0.91      1423
#
# avg / total       0.92      0.92      0.92      2966
#
# =============================================================
# ...done fitting
# =============================================================
# Testing with classifier Rand
# Prediction accuracy 0.918746
# [[ 0.96824368  0.03175632]
#  [ 0.13492621  0.86507379]]
#              precision    recall  f1-score   support
#
#         0.0       0.89      0.97      0.93      1543
#         1.0       0.96      0.87      0.91      1423
#
# avg / total       0.92      0.92      0.92      2966
#
# =============================================================

# %%
# Training the classifiers for the real time validation 
dataX = deepcopy(X) #[:-1]
dataY = deepcopy(Y) #[:-1]
data = np.array([(i,dataX[i],dataY[i]) for i in range(len(dataX))])
datapath = 'tmp/trained_pipes/'
scaler = StandardScaler() ; featsel = SelectKBest(k=1000,score_func= mutual_info_classif)
decomp = PCA(n_components=20)
pipe_list = [make_pipe_clf(scaler,featsel, decomp, classifiers[i]) for i in range(len(classifiers))]
filename2 = 'overall_models'
def pipefit(i,fs,pipe_id,pipe,train_x,dY):
    filename = 'fs'+'_'+str(i)+'_'+str(fs)+'_'+str(pipe_id)
    print(i,fs,pipe_id)
    pipefile = datapath+filename+'.npz'
    print("Started fitting...")
    model = pipe.fit(train_x, dY)
    print("...done fitting")
    np.savez(pipefile,model=np.array([model]))
    return model
def modelcomp(i,fs,dX,dY):
    return [Parallel(n_jobs=-1)([delayed(pipefit) (i,fs,pipe_id,pipe,dX,dY) for pipe_id, pipe in enumerate(pipe_list)])]

models = np.array([[modelcomp(i,fs,data_X[fs],data_Y) for fs in range(len(data_X))] for i,data_X,data_Y in data])
# Out:
# (0, 0, 0)
# Started fitting...
# (0, 0, 1)
# Started fitting...
# (0, 0, 2)
# Started fitting...
# (0, 0, 3)
# Started fitting...
# ...done fitting
# ...done fitting
# ...done fitting
# ...done fitting
# (0, 1, 0)
# Started fitting...
# (0, 1, 1)
# Started fitting...
# (0, 1, 2)
# Started fitting...
# (0, 1, 3)
# Started fitting...
# ...done fitting
# ...done fitting
# ...done fitting
# ...done fitting
# (0, 2, 0)
# Started fitting...
# (0, 2, 1)
# Started fitting...
# (0, 2, 2)
# Started fitting...
# (0, 2, 3)
# Started fitting...
# ...done fitting
# ...done fitting
# ...done fitting
# ...done fitting
# (1, 0, 0)
# Started fitting...
# (1, 0, 1)
# Started fitting...
# (1, 0, 2)
# Started fitting...
# (1, 0, 3)
# Started fitting...
# ...done fitting
# ...done fitting
# ...done fitting
# ...done fitting
# (1, 1, 0)
# Started fitting...
# (1, 1, 1)
# Started fitting...
# (1, 1, 2)
# Started fitting...
# (1, 1, 3)
# Started fitting...
# ...done fitting
# ...done fitting
# ...done fitting
# ...done fitting
# (1, 2, 0)
# Started fitting...
# (1, 2, 1)
# Started fitting...
# (1, 2, 2)
# Started fitting...
# (1, 2, 3)
# Started fitting...
# ...done fitting
# ...done fitting
# ...done fitting
# ...done fitting
# (2, 0, 0)
# Started fitting...
# (2, 0, 1)
# Started fitting...
# (2, 0, 2)
# Started fitting...
# (2, 0, 3)
# Started fitting...
# ...done fitting
# ...done fitting
# ...done fitting
# ...done fitting
# (2, 1, 0)
# Started fitting...
# (2, 1, 1)
# Started fitting...
# (2, 1, 2)
# Started fitting...
# (2, 1, 3)
# Started fitting...
# ...done fitting
# ...done fitting
# ...done fitting
# ...done fitting
# (2, 2, 0)
# Started fitting...
# (2, 2, 1)
# Started fitting...
# (2, 2, 2)
# Started fitting...
# (2, 2, 3)
# Started fitting...
# ...done fitting
# ...done fitting
# ...done fitting
# ...done fitting

# %%
models[:,:,0,:].shape
# Out:
# (3, 3, 4)

# %%
file2 = datapath + filename2 + '.npz'
np.savez(file2, models = models[:,:,0,:])

# %%
# anot = np.load(file2)['models']
# # print[mdl[i] for i in range(len(mdl))]
# # lasttry = [last + [mdl[i]] for i in range(len(mdl))]
# # anot[1].predict(trmp)
# anot[0,0,0].predict(dataX[0,0])
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])

# %%
XYsplitfile = 'tmp/features/1024_20/newfeatures_newdata_NOsample_trans_1024_20_10_10000_XYsplit.npz'
X = np.load(XYsplitfile)['Xsp']
Y = np.load(XYsplitfile)['Ysp']
print([ X[i][j].shape for i in range(len(X)) for j in range(len(X[i]))])
# Out:
# [(8953, 3107), (8953, 3107), (8953, 6214), (8953, 3107), (8953, 3107), (8953, 6214), (8952, 3107), (8952, 3107), (8952, 6214)]

# %%
# Training the classifiers for the real time validation 
dataX = deepcopy(X) #[:-1]
dataY = deepcopy(Y) #[:-1]
data = np.array([(i,dataX[i],dataY[i]) for i in range(len(dataX))])
datapath = 'tmp/trained_pipes_trans/'
scaler = StandardScaler() ; featsel = SelectKBest(k=1000,score_func= mutual_info_classif)
decomp = PCA(n_components=20)
pipe_list = [make_pipe_clf(scaler,featsel, decomp, classifiers[i]) for i in range(len(classifiers))]
filename3 = 'overall_models_trans'
def pipefit(i,fs,pipe_id,pipe,train_x,dY):
    filename = 'fs'+'_'+str(i)+'_'+str(fs)+'_'+str(pipe_id)
#     print(i,fs,pipe_id)
    pipefile = datapath+filename+'.npz'
    if os.path.isfile(pipefile):
        print("Found fitted "+str(i)+" "+str(fs)+" "+str(pipe_id)+"...")
        model = np.load(pipefile)['model'][0]
        print("Done loading "+str(i)+" "+str(fs)+" "+str(pipe_id)+"...")
    else:
        print("Started fitting "+str(i)+" "+str(fs)+" "+str(pipe_id)+"...")
        model = pipe.fit(train_x, dY)
        print("Done fitting "+str(i)+" "+str(fs)+" "+str(pipe_id)+"...")
        np.savez(pipefile,model=np.array([model]))
    return model
def modelcomp(i,fs,dX,dY):
    return [Parallel(n_jobs=-1)([delayed(pipefit) (i,fs,pipe_id,pipe,dX,dY) for pipe_id, pipe in enumerate(pipe_list)])]

models = np.array([[modelcomp(i,fs,data_X[fs],data_Y) for fs in range(len(data_X))] for i,data_X,data_Y in data])
print models.shape
# Out:
# Found fitted 0 0 0...
# Done loading 0 0 0...
# Found fitted 0 0 1...
# Done loading 0 0 1...
# Found fitted 0 0 2...
# Done loading 0 0 2...
# Found fitted 0 0 3...
# Done loading 0 0 3...
# Found fitted 0 1 0...
# Done loading 0 1 0...
# Found fitted 0 1 1...
# Done loading 0 1 1...
# Found fitted 0 1 2...
# Done loading 0 1 2...
# Found fitted 0 1 3...
# Done loading 0 1 3...
# Found fitted 0 2 0...
# Done loading 0 2 0...
# Found fitted 0 2 1...
# Done loading 0 2 1...
# Found fitted 0 2 2...
# Done loading 0 2 2...
# Found fitted 0 2 3...
# Done loading 0 2 3...
# Found fitted 1 0 0...
# Done loading 1 0 0...
# Found fitted 1 0 1...
# Done loading 1 0 1...
# Found fitted 1 0 2...
# Done loading 1 0 2...
# Found fitted 1 0 3...
# Done loading 1 0 3...
# Found fitted 1 1 0...
# Done loading 1 1 0...
# Found fitted 1 1 1...
# Done loading 1 1 1...
# Found fitted 1 1 2...
# Done loading 1 1 2...
# Found fitted 1 1 3...
# Done loading 1 1 3...
# Found fitted 1 2 0...
# Done loading 1 2 0...
# Found fitted 1 2 1...
# Done loading 1 2 1...
# Found fitted 1 2 2...
# Done loading 1 2 2...
# Found fitted 1 2 3...
# Done loading 1 2 3...
# Found fitted 2 0 0...
# Done loading 2 0 0...
# Found fitted 2 0 1...
# Done loading 2 0 1...
# Found fitted 2 0 2...
# Done loading 2 0 2...
# Found fitted 2 0 3...
# Done loading 2 0 3...
# Found fitted 2 1 0...
# Done loading 2 1 0...
# Found fitted 2 1 1...
# Done loading 2 1 1...
# Found fitted 2 1 2...
# Done loading 2 1 2...
# Found fitted 2 1 3...
# Done loading 2 1 3...
# Started fitting 2 2 0...
# Found fitted 2 2 1...
# Done loading 2 2 1...
# Found fitted 2 2 2...
# Done loading 2 2 2...
# Found fitted 2 2 3...
# Done loading 2 2 3...
# Done fitting 2 2 0...
# (3, 3, 1, 4)

# %%
file3 = datapath + filename3 + '.npz'
np.savez(file3, models = models[:,:,0,:])

# %%
mdl = np.load(file3)['models']
print mdl.shape
# Out:
# (3, 3, 4)

# %%
mdl[0,0,[0,1]].predict(dataX[0,0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d94be1db77a7> in <module>()
# ----> 1 mdl[0,0,[0,1]].predict(dataX[0,0])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'predict'
